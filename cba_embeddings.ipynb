# %% [markdown]
# This notebook trains word embedding spaces for CBA texts

# %%
# packages
import pandas as pd

from google.colab import drive

import gensim
from gensim.models import Word2Vec
import re

from gensim.models import KeyedVectors

import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
nltk.download("punkt")

from itertools import chain
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
## Mount drive
drive.mount('/content/drive')

## Load data
data_path = '/content/drive/My Drive/dhh21/'
file_name = 'cba_texts'
extension = '.csv'
df = pd.read_csv(data_path+file_name+extension, encoding='latin1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cba_id       1440 non-null   object
#  1   country      1440 non-null   object
#  2   countrycode  1440 non-null   int64
#  3   locale       1440 non-null   object
#  4   text         1440 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 56.4+ KB

# %%
# Make a column specifying just the language
df['language'] = df.apply(lambda row: row['locale'][:2], axis=1)

df['language'].unique()
# Out:
# array(['FR', 'EN', 'DA', 'MT', 'DE', 'SL', 'LT', 'SV', 'TR', 'IT', 'FI',
#        'BG', 'SK', 'CS', 'PT', 'NL', 'EL', 'RO', 'HR', 'ES', 'HU', 'ET',
#        'PL', 'KM', 'VI', 'BA', 'AM', 'SR'], dtype=object)

# %% [markdown]
# Each language gets one embedding space

# %% [markdown]
# ## Preprocessing

# %%
# Preprocessing

## Tokenization white-space

# Tokenize to sentences
df['sen_tokenized'] = df.apply(lambda row: nltk.sent_tokenize(row['text']), axis=1)

# Tokenize to words with white-space
tokenizer = RegexpTokenizer(r'\w+')
tokenized = []
for index, row in df.iterrows():
  sent = row['sen_tokenized']
  tokens = [tokenizer.tokenize(sentence) for sentence in sent]
  tokenized.append(tokens)

df['tokenized'] = tokenized

# Make a new column with the length of each tokenized article
df['length'] = df.apply(lambda row: sum([len(x) for x in row['tokenized']]), axis=1)

# Check the total amount of tokens
print("Total tokens data-set: ",sum(df['length']))

# Check one text
df['tokenized'][10]
# Out:
# Total tokens data-set:  32320515
# [['xml',
#   'version',
#   '1',
#   '0',
#   'encoding',
#   'UTF',
#   '8',
#   'meta',
#   'http',
#   'equiv',
#   'content',
#   'type',
#   'content',
#   'text',
#   'html',
#   'charset',
#   'UTF',
#   '8',
#   'title',
#   'calcestruzzo',
#   'title',
#   'meta',
#   'name',
#   'generator',
#   'content',
#   'Amaya',
#   'see',
#   'http',
#   'www',
#   'w3',
#   'org',
#   'Amaya',
#   'h1',
#   'Contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   '2003',
#   'h1',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'cbaratified',
#   'h2',
#   'Decreto',
#   'del',
#   'Consiglio',
#   'federale',
#   'che',
#   'conferisce',
#   'obbligatorietÃ',
#   'generale',
#   'al',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'del',
#   '10',
#   'luglio',
#   '2003',
#   'h2',
#   'div',
#   'p',
#   'fine',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'quanto',
#   'lo',
#   'richieda',
#   'il',
#   'disbrigo',
#   'delle',
#   'pendenze',
#   'o',
#   'di',
#   'altri',
#   'avvenimenti',
#   'che',
#   'rientrano',
#   'nella',
#   'durata',
#   'di',
#   'validitÃ',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro'],
#  ['La',
#   'Direzione',
#   'del',
#   'lavoro',
#   'puÃ²',
#   'inoltre',
#   'chiedere',
#   'per',
#   'visione',
#   'altri',
#   'documenti',
#   'e',
#   'informazioni',
#   'e',
#   'far',
#   'eseguire',
#   'controlli',
#   'a',
#   'carico',
#   'delle',
#   'parti',
#   'contraenti',
#   'p',
#   'h3',
#   'Art'],
#  ['4',
#   'h3',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'cbadate_start_date',
#   'p',
#   'Il',
#   'presente',
#   'decreto',
#   'entro',
#   'in',
#   'vigore',
#   'il',
#   '1Â',
#   'agosto',
#   '2003',
#   'ed',
#   'Ã',
#   'valido',
#   'sino',
#   'al',
#   '31',
#   'dicembre',
#   '2005',
#   'p',
#   'div',
#   'p',
#   '1',
#   '0',
#   'luglio',
#   '2003',
#   'In',
#   'nome',
#   'del',
#   'Consiglio',
#   'federale',
#   'svizzero',
#   'p',
#   'p',
#   'Il',
#   'presidente',
#   'della',
#   'Confederazione',
#   'Pascal',
#   'Couchepin',
#   'p',
#   'p',
#   'La',
#   'cancelliera',
#   'della',
#   'Confederazione',
#   'Annemarie',
#   'Huber',
#   'Hotz',
#   'p',
#   'h2',
#   'Appendice',
#   'Contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'h2',
#   'h2',
#   'concluso',
#   'il',
#   '15',
#   'luglio',
#   '2002',
#   'h2',
#   'p',
#   'tra',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'CBA_MNCOMPA_2_txt',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'CBA_MNCOMPA_1',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'SECTOR2',
#   'p',
#   'Swiss',
#   'Beton',
#   'e',
#   'lâ',
#   'Union',
#   'des',
#   'fabricants',
#   'de',
#   'produits',
#   'en',
#   'bÃ',
#   'ton',
#   'de',
#   'Suisse',
#   'Romande',
#   'da',
#   'una',
#   'parte',
#   'p',
#   'div',
#   'div',
#   'div',
#   'p',
#   'e',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'CBA_MEMTRAD4_1',
#   'p',
#   'il',
#   'Sindacato',
#   'Edilizia',
#   'amp',
#   'Industria',
#   'e',
#   'il',
#   'Sindacato',
#   'SYNA',
#   'dallâ',
#   'altra',
#   'parte',
#   'p',
#   'div',
#   'h2',
#   'Disposizioni',
#   'dichiarate',
#   'dâ',
#   'obbligatorietÃ',
#   'generale',
#   'h2',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'hourstxt',
#   'h3',
#   'Art'],
#  ['2',
#   'Orario',
#   'di',
#   'lavoro',
#   'h3',
#   'div',
#   'p',
#   '1',
#   'Il',
#   'normale',
#   'orario',
#   'di',
#   'lavoro',
#   'settimanale',
#   'Ã',
#   'di',
#   '42',
#   'ore'],
#  ['Per',
#   'i',
#   'lavori',
#   'a',
#   'turno',
#   'fa',
#   'stato',
#   'il',
#   'piano',
#   'dei',
#   'turni',
#   'approvato',
#   'dalle',
#   'autoritÃ',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'overtimeallowancetxt',
#   'p',
#   '2',
#   'La',
#   'ripartizione',
#   'delle',
#   'ore',
#   'di',
#   'lavoro',
#   'sui',
#   'giorni',
#   'della',
#   'settimana',
#   'viene',
#   'fissata',
#   'dal',
#   'datore',
#   'di',
#   'lavoro',
#   'previa',
#   'consultazione',
#   'con',
#   'la',
#   'commissione',
#   'di',
#   'fabbrica',
#   'o',
#   'con',
#   'i',
#   'le',
#   'lavorato',
#   'ri',
#   'trici'],
#  ['Il',
#   'datore',
#   'di',
#   'lavoro',
#   'Ã',
#   'libero',
#   'di',
#   'ripartire',
#   'il',
#   'lavoro',
#   'sullâ',
#   'arco',
#   'dellâ',
#   'intero',
#   'anno',
#   'in',
#   'modo',
#   'che',
#   'la',
#   'settimana',
#   'lavorativa',
#   'media',
#   'corrisponda',
#   'a',
#   '42',
#   'ore',
#   'p',
#   'div',
#   'p',
#   'p',
#   'p',
#   '4',
#   'Se',
#   'a',
#   'causa',
#   'di',
#   'guasti',
#   'o',
#   'problemi',
#   'nella',
#   'produzione',
#   'o',
#   'per',
#   'altri',
#   'motivi',
#   'il',
#   'lavoro',
#   'viene',
#   'interrotto',
#   'per',
#   'un',
#   'periodo',
#   'relativamente',
#   'breve',
#   'o',
#   'nel',
#   'caso',
#   'in',
#   'cui',
#   'al',
#   'la',
#   'lavoratore',
#   'trice',
#   'vengono',
#   'concesse',
#   'giornate',
#   'libere',
#   'dietro',
#   'sua',
#   'richiesta',
#   'in',
#   'deroga',
#   'allâ',
#   'orario',
#   'di',
#   'lavoro',
#   'settimanale',
#   'massimo',
#   'il',
#   'datore',
#   'di',
#   'lavoro',
#   'puÃ²',
#   'esigere',
#   'ai',
#   'sensi',
#   'della',
#   'legge',
#   'sul',
#   'lavoro',
#   'una',
#   'compensazione',
#   'delle',
#   'ore',
#   'lavorative',
#   'entro',
#   'un',
#   'periodo',
#   'di',
#   '12',
#   'settimane',
#   'p',
#   'p'],
#  ['p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'schedulestxt',
#   'p',
#   '6',
#   'Il',
#   'sabato',
#   'di',
#   'regola',
#   'non',
#   'si',
#   'lavora',
#   'p',
#   'div',
#   'p',
#   '7',
#   'Nelle',
#   'giornate',
#   'libere',
#   'possono',
#   'essere',
#   'svolte',
#   'attivitÃ',
#   'lavorative',
#   'a',
#   'scopo',
#   'di',
#   'lucro',
#   'solo',
#   'con',
#   'il',
#   'consenso',
#   'del',
#   'datore',
#   'di',
#   'lavoro',
#   'p',
#   'h3',
#   'h3',
#   'p'],
#  ['p',
#   'p',
#   '3',
#   'Di',
#   'comune',
#   'accordo',
#   'con',
#   'il',
#   'la',
#   'lavoratore',
#   'trice',
#   'il',
#   'datore',
#   'di',
#   'lavoro',
#   'puÃ²',
#   'compensare',
#   'entro',
#   'otto',
#   'settimane',
#   'il',
#   'lavoro',
#   'straordinario',
#   'con',
#   'tempo',
#   'libero',
#   'che',
#   'abbia',
#   'almeno',
#   'la',
#   'stessa',
#   'durata'],
#  ['Se',
#   'il',
#   'lavoro',
#   'straordinario',
#   'viene',
#   'compensato',
#   'con',
#   'tempo',
#   'libero',
#   'il',
#   'datore',
#   'di',
#   'lavoro',
#   'puÃ²',
#   'scegliere',
#   'se',
#   'compensare',
#   'il',
#   'supplemento',
#   'con',
#   'denaro',
#   'o',
#   'tempo',
#   'libero'],
#  ['Se',
#   'il',
#   'lavoro',
#   'straordinario',
#   'non',
#   'viene',
#   'compensato',
#   'con',
#   'tempo',
#   'libero',
#   'il',
#   'datore',
#   'di',
#   'lavoro',
#   'Ã',
#   'tenuto',
#   'a',
#   'corrispondere',
#   'un',
#   'supplemento',
#   'del',
#   '25'],
#  ['Per',
#   'il',
#   'lavoro',
#   'straordinario',
#   'eseguito',
#   'la',
#   'domenica',
#   'o',
#   'nei',
#   'giorni',
#   'festivi',
#   'il',
#   'supplemento',
#   'Ã',
#   'pari',
#   'al',
#   '50',
#   'p',
#   'p',
#   '4',
#   'Restano',
#   'escluse',
#   'le',
#   'disposizioni',
#   'per',
#   'lâ',
#   'indennitÃ',
#   'del',
#   'lavoro',
#   'a',
#   'turni',
#   'p',
#   'p',
#   '5',
#   'Nei',
#   'giorni',
#   'festivi',
#   'soggetti',
#   'ad',
#   'indennitÃ',
#   'al',
#   'la',
#   'lavoratore',
#   'trice',
#   'viene',
#   'corrisposto',
#   'il',
#   'salario',
#   'con',
#   'il',
#   'relativo',
#   'supplemento'],
#  ['Tali',
#   'giorni',
#   'festivi',
#   'devono',
#   'essere',
#   'compensati',
#   'con',
#   'un',
#   'altro',
#   'giorno',
#   'di',
#   'tempo',
#   'libero',
#   'oppure',
#   'devono',
#   'essere',
#   'indennizzati',
#   'quali',
#   'giorni',
#   'festivi',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'WAGES_comments_txt',
#   'h3',
#   'Art'],
#  ['4',
#   'Salario',
#   'h3',
#   'p',
#   '1',
#   'Ai',
#   'alle',
#   'lavoratori',
#   'trici',
#   'viene',
#   'corrisposto',
#   'un',
#   'salario',
#   'mensile'],
#  ['La',
#   'base',
#   'di',
#   'calcolo',
#   'Ã',
#   'data',
#   'da',
#   '182',
#   '5',
#   'ore',
#   'mensili',
#   'p',
#   'div',
#   'p',
#   'p',
#   'p',
#   'b',
#   'A',
#   'Salari',
#   'minimi',
#   'b',
#   'p',
#   'p',
#   'Per',
#   'i',
#   'le',
#   'lavoratori',
#   'lavoratrici',
#   'pienamente',
#   'abili',
#   'al',
#   'lavoro',
#   'con',
#   'piÃ¹',
#   'di',
#   '19',
#   'anni',
#   'i',
#   'salari',
#   'minimi',
#   'concordati',
#   'ammontano',
#   'a',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'JOBTYPE_comments_txt',
#   'div',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'WAGES_payscale1_end',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'WAGES_payscale1_start',
#   'div',
#   'div',
#   'table',
#   'border',
#   '1',
#   'caption',
#   'caption',
#   'colgroup',
#   'col',
#   'col',
#   'colgroup',
#   'tbody',
#   'tr',
#   'tr',
#   'tr',
#   'tr',
#   'tr',
#   'td',
#   'lavoratori',
#   'trici',
#   'non',
#   'qualificati',
#   'e',
#   'td',
#   'td',
#   'fr',
#   '3800',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'lavoratori',
#   'trici',
#   'semiqualificati',
#   'e',
#   'td',
#   'td',
#   'fr',
#   '3900',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'lavoratori',
#   'trici',
#   'qualificati',
#   'e',
#   'td',
#   'td',
#   'fr',
#   '4200',
#   'td',
#   'tr',
#   'tr',
#   'tr',
#   'tr',
#   'tr',
#   'tbody',
#   'table',
#   'p',
#   'In',
#   'caso',
#   'di',
#   'nuova',
#   'assunzione',
#   'nel',
#   'primo',
#   'anno',
#   'di',
#   'servizio',
#   'il',
#   'salario',
#   'puÃ²',
#   'essere',
#   'ridotto',
#   'di',
#   'fr'],
#  ['200', 'p', 'p'],
#  ['p', 'p', 'b', 'B'],
#  ['Tredicesima',
#   'mensilitÃ',
#   'b',
#   'p',
#   'p',
#   '1',
#   'Alla',
#   'fine',
#   'dellâ',
#   'anno',
#   'civile',
#   'i',
#   'lavoratori',
#   'e',
#   'le',
#   'lavoratrici',
#   'hanno',
#   'diritto',
#   'ad',
#   'una',
#   'tredicesima',
#   'mensilitÃ',
#   'pari',
#   'allâ',
#   '8',
#   '33',
#   'del',
#   'salario',
#   'totale',
#   'percepito',
#   'nelIâ',
#   'anno',
#   'civile',
#   'in',
#   'oggetto',
#   'senza',
#   'supplementi',
#   'o',
#   'compensi',
#   'per',
#   'lavoro',
#   'straordinario'],
#  ['Anche',
#   'la',
#   'tredicesima',
#   'mensilitÃ',
#   'deve',
#   'rientrare',
#   'nellâ',
#   'assicurazione',
#   'di',
#   'indennitÃ',
#   'giornaliera',
#   'di',
#   'malattia',
#   'p',
#   'p',
#   '2',
#   'Il',
#   'datore',
#   'di',
#   'lavoro',
#   'Ã',
#   'autorizzato',
#   'a',
#   'computare',
#   'gratifiche',
#   'o',
#   'altre',
#   'prestazioni',
#   'supplementari',
#   'di',
#   'fine',
#   'anno',
#   'con',
#   'la',
#   'tredicesima',
#   'mensilitÃ',
#   'p',
#   'p',
#   '3',
#   'Anche',
#   'le',
#   'apprendiste',
#   'e',
#   'gli',
#   'apprendisti',
#   'hanno',
#   'diritto',
#   'a',
#   'percepire',
#   'la',
#   'tredicesima',
#   'mensilitÃ',
#   'p',
#   'p',
#   'b',
#   'C',
#   'Lavoro',
#   'a',
#   'turni',
#   'b',
#   'p',
#   'p',
#   'Per',
#   'le',
#   'aziende',
#   'che',
#   'adottano',
#   'lâ',
#   'orario',
#   'di',
#   'lavoro',
#   'a',
#   'due',
#   'turni',
#   'il',
#   'supplemento',
#   'ammonta',
#   'a',
#   'fr'],
#  ['1', '20', 'allâ', 'ora', 'p', 'p'],
#  ['p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'PAIDLEAV_trigger',
#   'h3',
#   'Art'],
#  ['5',
#   'Vacanze',
#   'h3',
#   'div',
#   'p',
#   '1',
#   'Diritto',
#   'p',
#   'table',
#   'border',
#   '1',
#   'caption',
#   'caption',
#   'colgroup',
#   'col',
#   'col',
#   'col',
#   'col',
#   'colgroup',
#   'tbody',
#   'tr',
#   'td',
#   'td',
#   'tr',
#   'tbody',
#   'table',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'holidaystxt',
#   'table',
#   'border',
#   '1',
#   'tbody',
#   'tr',
#   'td',
#   'td',
#   'td',
#   '2003',
#   'td',
#   'td',
#   '2004',
#   'td',
#   'td',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'a',
#   'partire',
#   'dal',
#   '1',
#   'Â',
#   'anno',
#   'di',
#   'servizio',
#   'td',
#   'td',
#   '24',
#   '0',
#   'td',
#   'td',
#   '25',
#   '0',
#   'td',
#   'td',
#   'giorni',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'dopo',
#   '15',
#   'anni',
#   'di',
#   'servizio',
#   'nellâ',
#   'azienda',
#   'td',
#   'td',
#   '26',
#   '5',
#   'td',
#   'td',
#   '27',
#   '5',
#   'td',
#   'td',
#   'giorni',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'dopo',
#   'il',
#   'compimento',
#   'del',
#   '50Â',
#   'anno',
#   'di',
#   'etÃ',
#   'td',
#   'td',
#   '29',
#   '0',
#   'td',
#   'td',
#   '30',
#   '0',
#   'td',
#   'td',
#   'giorni',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'fino',
#   'a',
#   '20',
#   'anni',
#   'compiuti',
#   'p',
#   'valido',
#   'anche',
#   'per',
#   'gli',
#   'le',
#   'apprendisti',
#   'e',
#   'p',
#   'td',
#   'td',
#   '29',
#   '0',
#   'td',
#   'td',
#   '30',
#   '0',
#   'td',
#   'td',
#   'giorni',
#   'td',
#   'tr',
#   'tbody',
#   'table',
#   'div',
#   'p',
#   '2',
#   'Il',
#   'diritto',
#   'alle',
#   'vacanze',
#   'viene',
#   'calcolato',
#   'pro',
#   'rata',
#   'e',
#   'per',
#   'ogni',
#   'anno',
#   'civile',
#   'p',
#   'p',
#   '3',
#   'Se',
#   'lâ',
#   'assenza',
#   'dal',
#   'lavoro',
#   'per',
#   'causa',
#   'di',
#   'malattia',
#   'infortunio',
#   'adempimento',
#   'a',
#   'doveri',
#   'legali',
#   'o',
#   'esercizio',
#   'di',
#   'una',
#   'carica',
#   'pubblica',
#   'non',
#   'dura',
#   'piÃ¹',
#   'di',
#   'un',
#   'mese',
#   'il',
#   'diritto',
#   'alle',
#   'vacanze',
#   'non',
#   'subisce',
#   'riduzioni'],
#  ['Il',
#   'servizio',
#   'militare',
#   'svizzero',
#   'della',
#   'durata',
#   'inferiore',
#   'ad',
#   'un',
#   'mese',
#   'non',
#   'viene',
#   'computato',
#   'ai',
#   'fini',
#   'della',
#   'riduzione',
#   'del',
#   'diritto',
#   'alle',
#   'vacanze'],
#  ['Ai',
#   'lavoratori',
#   'e',
#   'alle',
#   'lavoratrici',
#   'che',
#   'nellâ',
#   'anno',
#   'in',
#   'corso',
#   'hanno',
#   'giÃ',
#   'beneficiato',
#   'del',
#   'loro',
#   'diritto',
#   'alle',
#   'vacanze',
#   'e',
#   'che',
#   'disdicono',
#   'il',
#   'loro',
#   'rapporto',
#   'di',
#   'lavoro',
#   'o',
#   'che',
#   'vengono',
#   'licenziati',
#   'per',
#   'cause',
#   'gravi',
#   'ai',
#   'sensi',
#   'dellâ',
#   'articolo',
#   '337',
#   'CO',
#   'al',
#   'momento',
#   'del',
#   'licenziamento',
#   'sarÃ',
#   'trattenuta',
#   'la',
#   'quota',
#   'corrispondente',
#   'ai',
#   'giorni',
#   'di',
#   'vacanza',
#   'in',
#   'eccesso',
#   'di',
#   'cui',
#   'hanno',
#   'giÃ',
#   'beneficiato',
#   'p',
#   'p',
#   'p',
#   'h3',
#   'Art'],
#  ['6',
#   'Giorni',
#   'festivi',
#   'h3',
#   'p',
#   'Tutte',
#   'le',
#   'lavoratrici',
#   'e',
#   'tutti',
#   'i',
#   'lavoratori',
#   'compresi',
#   'quelli',
#   'che',
#   'lavorano',
#   'a',
#   'turni',
#   'hanno',
#   'diritto',
#   'a',
#   '9',
#   'giorni',
#   'festivi',
#   'retribuiti',
#   'in',
#   'conformitÃ',
#   'agli',
#   'usi',
#   'locali',
#   'o',
#   'alle',
#   'disposizioni',
#   'legislative',
#   'se',
#   'questi',
#   'cadono',
#   'in',
#   'un',
#   'giorno',
#   'di',
#   'lavoro',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'deathrelativestxt',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'paidpaternityleavetxt',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'paidmaternityleavetxt',
#   'h3',
#   'Art'],
#  ['7',
#   'IndennitÃ',
#   'per',
#   'assenze',
#   'h3',
#   'div',
#   'div',
#   'div',
#   'p',
#   '1',
#   'Per',
#   'le',
#   'seguenti',
#   'assenze',
#   'le',
#   'lavoratrici',
#   'e',
#   'i',
#   'lavoratori',
#   'usufruiscono',
#   'di',
#   'unâ',
#   'indennitÃ',
#   'rinuncia',
#   'a',
#   'deduzioni',
#   'dal',
#   'salario',
#   'mensile'],
#  ['p',
#   'table',
#   'border',
#   '1',
#   'caption',
#   'caption',
#   'colgroup',
#   'col',
#   'col',
#   'colgroup',
#   'tbody',
#   'tr',
#   'td',
#   'decesso',
#   'del',
#   'la',
#   'coniuge',
#   'del',
#   'la',
#   'compagno',
#   'a',
#   'con',
#   'cui',
#   'il',
#   'la',
#   'lavoratore',
#   'trice',
#   'ha',
#   'vissuto',
#   'un',
#   'rapporto',
#   'simile',
#   'al',
#   'matrimonio',
#   'per',
#   'un',
#   'periodo',
#   'prolungato',
#   'dei',
#   'genitori',
#   'o',
#   'dei',
#   'propri',
#   'figli',
#   'td',
#   'td',
#   '3',
#   'giorni',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'nascita',
#   'di',
#   'figli'],
#  ['matrimonio',
#   'proprio',
#   'decesso',
#   'di',
#   'un',
#   'fratello',
#   'o',
#   'di',
#   'una',
#   'sorella',
#   'dei',
#   'nonni',
#   'o',
#   'dei',
#   'suoceri',
#   'td',
#   'td',
#   '1',
#   'giorno',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'ispezione',
#   'militare',
#   'dellâ',
#   'equipaggiamento',
#   'e',
#   'delle',
#   'armi',
#   'compresa',
#   'la',
#   'protezione',
#   'civile',
#   'td',
#   'td',
#   '1',
#   '2',
#   'giornata',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'trasferimento',
#   'del',
#   'proprio',
#   'domicilio',
#   'td',
#   'td',
#   '1',
#   'giorno',
#   'td',
#   'tr',
#   'tbody',
#   'table',
#   'p',
#   '2',
#   'Se',
#   'la',
#   'partecipazione',
#   'allâ',
#   'ispezione',
#   'militare',
#   'richiede',
#   'piÃ¹',
#   'di',
#   'mezza',
#   'giornata',
#   'viene',
#   'indennizzato',
#   'il',
#   'tempo',
#   'necessario',
#   'fino',
#   'ad',
#   'un',
#   'massimo',
#   'di',
#   'una',
#   'giornata',
#   'p',
#   'p',
#   '3',
#   'Per',
#   'altre',
#   'assenze',
#   'inevitabili',
#   'di',
#   'breve',
#   'durata',
#   'esercizio',
#   'di',
#   'cariche',
#   'pubbliche',
#   'adem',
#   'pimento',
#   'a',
#   'doveri',
#   'legali',
#   'a',
#   'condizione',
#   'che',
#   'siano',
#   'annunciate',
#   'e',
#   'giustificate',
#   'in',
#   'anticipo',
#   'il',
#   'tempo',
#   'necessario',
#   'p',
#   'p',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'ADMINISTRATIVE_trigger',
#   'h3',
#   'Art'],
#  ['8',
#   'IndennitÃ',
#   'per',
#   'servizio',
#   'militare',
#   'h3',
#   'div',
#   'p',
#   '1',
#   'Il',
#   'lavoratore',
#   'ha',
#   'diritto',
#   'ad',
#   'unâ',
#   'indennitÃ',
#   'per',
#   'i',
#   'giorni',
#   'lavorativi',
#   'persi',
#   'durante',
#   'il',
#   'servizio',
#   'militare',
#   'svizzero',
#   'obbligatorio',
#   'o',
#   'altri',
#   'servizi',
#   'parificati',
#   'protezione',
#   'civile'],
#  ['Lâ',
#   'indennitÃ',
#   'Ã',
#   'calcolata',
#   'in',
#   'base',
#   'al',
#   'salario',
#   'come',
#   'segue',
#   'p',
#   'table',
#   'border',
#   '1',
#   'caption',
#   'caption',
#   'colgroup',
#   'col',
#   'col',
#   'colgroup',
#   'tbody',
#   'tr',
#   'td',
#   'scuola',
#   'reclute',
#   'td',
#   'td',
#   '100',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'restanti',
#   'servizi',
#   'militari',
#   'fino',
#   'a',
#   '4',
#   'settimane',
#   'per',
#   'anno',
#   'civile',
#   'td',
#   'td',
#   '100',
#   'td',
#   'tr',
#   'tr',
#   'td',
#   'servizi',
#   'militari',
#   'superiori',
#   'a',
#   '4',
#   'settimane',
#   'fino',
#   'a',
#   '21',
#   'settimane',
#   'per',
#   'anno',
#   'civile',
#   'td',
#   'td',
#   '80',
#   'td',
#   'tr',
#   'tbody',
#   'table',
#   'p',
#   '2',
#   'Tale',
#   'indennitÃ',
#   'spetta',
#   'solo',
#   'se',
#   'il',
#   'rapporto',
#   'di',
#   'lavoro',
#   'ha',
#   'una',
#   'durata',
#   'di',
#   'almeno',
#   '6',
#   'mesi',
#   'prima',
#   'e',
#   'dopo',
#   'la',
#   'prestazione',
#   'del',
#   'servizio',
#   'militare',
#   'e',
#   'non',
#   'viene',
#   'disdetto',
#   'dal',
#   'lavoratore',
#   'al',
#   'momento',
#   'della',
#   'ripresa',
#   'del',
#   'lavoro'],
#  ['Se',
#   'il',
#   'lavoratore',
#   'disdice',
#   'il',
#   'rapporto',
#   'di',
#   'lavoro',
#   'prima',
#   'che',
#   'siano',
#   'decorsi',
#   'questi',
#   '6',
#   'mesi',
#   'ha',
#   'diritto',
#   'solo',
#   'alle',
#   'prestazioni',
#   'ai',
#   'sensi',
#   'del',
#   'Codice',
#   'delle',
#   'obbligazioni',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'healthinsurancetxt',
#   'h3',
#   'Art'],
#  ['10',
#   'Assicurazione',
#   'per',
#   'indennitÃ',
#   'giornaliera',
#   'di',
#   'malattia',
#   'h3',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'sicknessmaxdaystxt',
#   'p',
#   '1',
#   'Il',
#   'datore',
#   'di',
#   'lavoro',
#   'deve',
#   'stipulare',
#   'unâ',
#   'assicurazione',
#   'dâ',
#   'indennitÃ',
#   'giornaliera',
#   'di',
#   'malattia',
#   'per',
#   'i',
#   'lavoratori',
#   'sottoposti',
#   'al',
#   'presente',
#   'contratto'],
#  ['Le',
#   'disposizioni',
#   'assicurative',
#   'devono',
#   'essere',
#   'conformi',
#   'alla',
#   'LAMal',
#   'e',
#   'garantire',
#   'in',
#   'particolare',
#   'il',
#   'rispetto',
#   'assoluto',
#   'degli',
#   'articoli',
#   '72',
#   'e',
#   '74',
#   'della',
#   'LAMal',
#   'e',
#   'del',
#   'diritto',
#   'di',
#   'passare',
#   'allâ',
#   'assicurazione',
#   'individuale'],
#  [],
#  ['p',
#   'div',
#   'div',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'sicknesspaytxt',
#   'p',
#   'Le',
#   'condizioni',
#   'assicurative',
#   'devono',
#   'prevedere',
#   'una',
#   'copertura',
#   'pari',
#   'allâ',
#   '80',
#   'del',
#   'salario',
#   'tredicesima',
#   'mensilitÃ',
#   'compresa',
#   'a',
#   'partire',
#   'dal',
#   'primo',
#   'giorno',
#   'di',
#   'malattia',
#   'p',
#   'p',
#   '2',
#   'Il',
#   'datore',
#   'di',
#   'lavoro',
#   'versa',
#   'il',
#   '70',
#   'del',
#   'premio',
#   'per',
#   'lâ',
#   'assicurazione',
#   'dâ',
#   'indennitÃ',
#   'giornaliera',
#   'che',
#   'prevede',
#   'la',
#   'suddetta',
#   'copertura',
#   'p',
#   'div',
#   'p',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'unemploymentfundtxt',
#   'h3',
#   'Art'],
#  ['11',
#   'Assunzione',
#   'e',
#   'licenziamento',
#   'h3',
#   'div',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'contracttrialtxt',
#   'p',
#   '1',
#   'I',
#   'primi',
#   'due',
#   'mesi',
#   'dopo',
#   'lâ',
#   'assunzione',
#   'vengono',
#   'considerati',
#   'come',
#   'periodo',
#   'di',
#   'prova'],
#  ['In',
#   'tale',
#   'periodo',
#   'il',
#   'rapporto',
#   'di',
#   'lavoro',
#   'puÃ²',
#   'essere',
#   'sciolto',
#   'in',
#   'ogni',
#   'momento',
#   'da',
#   'entrambe',
#   'le',
#   'parti',
#   'rispettando',
#   'un',
#   'termine',
#   'di',
#   'disdetta',
#   'di',
#   '7',
#   'giorni',
#   'p',
#   'p',
#   '2',
#   'Dopo',
#   'il',
#   'periodo',
#   'di',
#   'prova',
#   'il',
#   'rapporto',
#   'di',
#   'lavoro',
#   'puÃ²',
#   'essere',
#   'sciolto',
#   'da',
#   'entrambe',
#   'le',
#   'parti',
#   'per',
#   'la',
#   'fine',
#   'di',
#   'un',
#   'mese',
#   'rispettando',
#   'i',
#   'seguenti',
#   'periodi',
#   'di',
#   'disdetta',
#   'p',
#   'p',
#   'nel',
#   'primo',
#   'anno',
#   'di',
#   'servizio',
#   '1mese',
#   'p',
#   'p',
#   'dal',
#   '2Â',
#   'al',
#   '5Â',
#   'anno',
#   'di',
#   'servizio2mesi',
#   'p',
#   'p',
#   'dal',
#   '6Â',
#   'anno',
#   'di',
#   'servizio',
#   '3mesi',
#   'p',
#   'p',
#   '3',
#   'La',
#   'disdetta',
#   'deve',
#   'pervenire',
#   'al',
#   'destinatario',
#   'prima',
#   'dellâ',
#   'inizio',
#   'del',
#   'periodo',
#   'di',
#   'disdetta',
#   'p',
#   'div',
#   'p',
#   'p',
#   'h3',
#   'Art'],
#  ['14',
#   'ComunitÃ',
#   'contrattuale',
#   'h3',
#   'p',
#   'Ai',
#   'sensi',
#   'dellâ',
#   'articolo',
#   '357b',
#   'CO',
#   'le',
#   'parti',
#   'contraenti',
#   'hanno',
#   'il',
#   'diritto',
#   'comune',
#   'di',
#   'esigere',
#   'lâ',
#   'adempimento',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'da',
#   'parte',
#   'dei',
#   'datori',
#   'di',
#   'lavoro',
#   'e',
#   'dei',
#   'lavoratori',
#   'interessati'],
#  [],
#  ['p', 'h3', 'Art'],
#  ['15',
#   'Contributo',
#   'per',
#   'le',
#   'spese',
#   'di',
#   'esecuzione',
#   'h3',
#   'p',
#   '1',
#   'Per',
#   'la',
#   'copertura',
#   'dei',
#   'costi',
#   'derivanti',
#   'dallâ',
#   'esecuzione',
#   'del',
#   'presente',
#   'contratto',
#   'e',
#   'per',
#   'la',
#   'realizzazione',
#   'di',
#   'altri',
#   'compiti',
#   'del',
#   'Parifonds',
#   'quali',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'trainingfundtxt',
#   'p',
#   'finanziamento',
#   'di',
#   'corsi',
#   'per',
#   'la',
#   'formazione',
#   'e',
#   'il',
#   'perfezionamento',
#   'professionali',
#   'tecnica',
#   'lingue',
#   'straniere',
#   'e',
#   'conoscenze',
#   'informatiche',
#   'p',
#   'div',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'apprenticeshipstxt',
#   'p',
#   'finanziamento',
#   'di',
#   'corsi',
#   'introduttivi',
#   'per',
#   'costruttori',
#   'di',
#   'prefabbricati',
#   'apprendisti',
#   'p',
#   'div',
#   'p',
#   'pagamento',
#   'della',
#   'perdita',
#   'di',
#   'salario',
#   'per',
#   'la',
#   'partecipazione',
#   'ai',
#   'corsi',
#   'sovvenzionati',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'healthandsafetypolicy',
#   'p',
#   'sovvenzione',
#   'per',
#   'mezzi',
#   'ausiliari',
#   'non',
#   'previsti',
#   'dalla',
#   'legislazione',
#   'vigente',
#   'per',
#   'aumentare',
#   'la',
#   'sicurezza',
#   'del',
#   'lavoro',
#   'e',
#   'la',
#   'protezione',
#   'della',
#   'salute',
#   'p',
#   'div',
#   'p',
#   'sovvenzione',
#   'a',
#   'favore',
#   'di',
#   'lavoratori',
#   'trici',
#   'che',
#   'rappresentano',
#   'dei',
#   'casi',
#   'di',
#   'rigore',
#   'tutti',
#   'i',
#   'le',
#   'lavoratori',
#   'trici',
#   'gli',
#   'le',
#   'apprendisti',
#   'e',
#   'e',
#   'i',
#   'datori',
#   'di',
#   'lavoro',
#   'sottoposti',
#   'al',
#   'presente',
#   'contratto',
#   'versano',
#   'un',
#   'contributo',
#   'p',
#   'p',
#   'Il',
#   'contributo',
#   'mensile',
#   'dei',
#   'datori',
#   'di',
#   'lavoro',
#   'ammonta',
#   'a',
#   'fr'],
#  ['3',
#   'per',
#   'ogni',
#   'collaborato',
#   're',
#   'trice',
#   'sottoposto',
#   'a',
#   'al',
#   'presente',
#   'contratto',
#   'p',
#   'p',
#   'Il',
#   'contributo',
#   'mensile',
#   'dei',
#   'delle',
#   'lavoratori',
#   'trici',
#   'ammonta',
#   'a',
#   'fr'],
#  ['12',
#   'per',
#   'ogni',
#   'lavorato',
#   're',
#   'trice',
#   'sottoposto',
#   'a',
#   'al',
#   'presente',
#   'contratto',
#   'p',
#   'p',
#   'I',
#   'le',
#   'costruttori',
#   'trici',
#   'di',
#   'prefabbricati',
#   'apprendisti',
#   'versano',
#   'un',
#   'contributo',
#   'mensile',
#   'di',
#   'fr'],
#  ['5',
#   'p',
#   'p',
#   '2',
#   'Ai',
#   'fini',
#   'della',
#   'riscossione',
#   'dei',
#   'contributi',
#   'entro',
#   'la',
#   'fine',
#   'dellâ',
#   'anno',
#   'civile',
#   'ogni',
#   'datore',
#   'di',
#   'lavoro',
#   'Ã',
#   'tenuto',
#   'ad',
#   'inoltrare',
#   'alla',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'un',
#   'elenco',
#   'relativo',
#   'allâ',
#   'anno',
#   'trascorso',
#   'contenente',
#   'tutti',
#   'i',
#   'nominativi',
#   'delle',
#   'lavoratrici',
#   'e',
#   'dei',
#   'lavoratori',
#   'sottoposti',
#   'al',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro'],
#  ['Per',
#   'ogni',
#   'nominativo',
#   'lâ',
#   'elenco',
#   'deve',
#   'indicare',
#   'la',
#   'funzione',
#   'il',
#   'domicilio',
#   'la',
#   'durata',
#   'del',
#   'rapporto',
#   'di',
#   'lavoro',
#   'e',
#   'lâ',
#   'importo',
#   'complessivo',
#   'dei',
#   'contributi',
#   'detratti',
#   'p',
#   'p',
#   '3',
#   'La',
#   'riscossione',
#   'e',
#   'il',
#   'pagamento',
#   'delle',
#   'sovvenzioni',
#   'vengono',
#   'gestiti',
#   'dallâ',
#   'associazione',
#   'Parifonds',
#   'dellâ',
#   'industria',
#   'svizzera',
#   'di',
#   'prodotti',
#   'in',
#   'calcestruzzo'],
#  [],
#  ['p', 'h3', 'Art'],
#  ['17', 'Diritto', 'di', 'coalizione', 'h3', 'p'],
#  ['Nessun',
#   'a',
#   'lavoratore',
#   'trice',
#   'deve',
#   'essere',
#   'penalizzato',
#   'in',
#   'base',
#   'alla',
#   'propria',
#   'appartenenza',
#   'o',
#   'non',
#   'appartenenza',
#   'ad',
#   'una',
#   'organizzazione',
#   'dei',
#   'lavoratori',
#   'nÃ',
#   'ad',
#   'opera',
#   'dellâ',
#   'azienda',
#   'nÃ',
#   'ad',
#   'opera',
#   'dei',
#   'delle',
#   'lavoratori',
#   'trici',
#   'p',
#   'h3',
#   'Art'],
#  ['18',
#   'Commissione',
#   'di',
#   'fabbrica',
#   'h3',
#   'p',
#   '1',
#   '1',
#   'lavoratori',
#   'e',
#   'le',
#   'lavoratrici',
#   'di',
#   'ogni',
#   'azienda',
#   'hanno',
#   'il',
#   'diritto',
#   'di',
#   'costituire',
#   'una',
#   'com',
#   'missione',
#   'di',
#   'fabbrica',
#   'costituita',
#   'da',
#   'almeno',
#   '3',
#   'membri'],
#  ['Lâ',
#   'elezione',
#   'avviene',
#   'secondo',
#   'una',
#   'procedura',
#   'alla',
#   'quale',
#   'vengono',
#   'invitati',
#   'ed',
#   'ammessi',
#   'con',
#   'paritÃ',
#   'di',
#   'diritti',
#   'e',
#   'di',
#   'doveri',
#   'tutti',
#   'i',
#   'dipendenti',
#   'dellâ',
#   'azienda',
#   'interessata',
#   'lâ',
#   'elezione',
#   'deve',
#   'tener',
#   'conto',
#   'dei',
#   'diversi',
#   'gruppi',
#   'di',
#   'lavoro',
#   'p',
#   'p',
#   '2',
#   'La',
#   'commissione',
#   'di',
#   'fabbrica',
#   'viene',
#   'informata',
#   'dalla',
#   'direzione',
#   'dellâ',
#   'impresa',
#   'in',
#   'merito',
#   'a',
#   'tutte',
#   'le',
#   'questioni',
#   'concernenti',
#   'i',
#   'rapporti',
#   'di',
#   'lavoro',
#   'e',
#   'partecipa',
#   'alla',
#   'soluzione',
#   'di',
#   'tali',
#   'questioni'],
#  ['p',
#   'p',
#   '3',
#   'Eventuali',
#   'divergenze',
#   'che',
#   'non',
#   'possano',
#   'essere',
#   'risolte',
#   'direttamente',
#   'tra',
#   'datore',
#   'di',
#   'lavoro',
#   'e',
#   'commissione',
#   'di',
#   'fabbrica',
#   'rispettivamente',
#   'maestranze',
#   'vengono',
#   'deferite',
#   'alla',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'art'],
#  ['20', 'p', 'h3', 'Art'],
#  ['19',
#   'Pubblicazione',
#   'h3',
#   'p',
#   'Il',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro'],
#  ['deve',
#   'essere',
#   'affisso',
#   'in',
#   'modo',
#   'ben',
#   'visibile',
#   'in',
#   'ogni',
#   'azienda',
#   'p',
#   'h3',
#   'Art'],
#  ['20',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'h3',
#   'p',
#   '1',
#   'Ai',
#   'fini',
#   'della',
#   'comune',
#   'attuazione',
#   'del',
#   'presente',
#   'CCL',
#   'ai',
#   'sensi',
#   'dellâ',
#   'articolo',
#   '357b',
#   'CO',
#   'Ã',
#   'costituita',
#   'una',
#   'Commissione',
#   'professionale',
#   'paritetica'],
#  ['p',
#   'p',
#   '2',
#   'La',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'svolge',
#   'in',
#   'particolare',
#   'i',
#   'seguenti',
#   'compiti',
#   'p',
#   'p',
#   'a'],
#  ['mediazione',
#   'in',
#   'caso',
#   'di',
#   'controversie',
#   'tra',
#   'datori',
#   'di',
#   'lavoro',
#   'e',
#   'lavoratori',
#   'trici',
#   'risp'],
#  ['commissioni', 'di', 'fabbrica', 'p', 'p'],
#  ['p', 'p', 'c'],
#  ['esercizio',
#   'del',
#   'diritto',
#   'di',
#   'accertamento',
#   'di',
#   'violazioni',
#   'contrattuali',
#   'disposizioni',
#   'legislative',
#   'o',
#   'altri',
#   'obblighi',
#   'piÃ¹',
#   'specifici',
#   'stabiliti',
#   'nel',
#   'CCL',
#   'p',
#   'p',
#   'd'],
#  ['attuazione',
#   'di',
#   'controlli',
#   'sullâ',
#   'osservanza',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'p',
#   'p',
#   'e'],
#  ['comminazione',
#   'e',
#   'riscossione',
#   'delle',
#   'pene',
#   'convenzionali',
#   'e',
#   'addebito',
#   'delle',
#   'relative',
#   'spese',
#   'di',
#   'controllo',
#   'e',
#   'procedura',
#   'p',
#   'p'],
#  ['p', 'h3', 'Art'],
#  ['21',
#   'Pene',
#   'convenzionali',
#   'h3',
#   'p',
#   '1',
#   'La',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'puÃ²',
#   'infliggere',
#   'una',
#   'pena',
#   'convenzionale',
#   'fino',
#   'a',
#   'fr'],
#  ['50',
#   '000',
#   'ai',
#   'datori',
#   'di',
#   'lavoro',
#   'e',
#   'ai',
#   'alle',
#   'lavoratori',
#   'trici',
#   'che',
#   'non',
#   'rispettano',
#   'gli',
#   'obblighi',
#   'derivanti',
#   'dal',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro'],
#  ['La',
#   'pena',
#   'convenzionale',
#   'viene',
#   'fissata',
#   'innanzitutto',
#   'in',
#   'modo',
#   'da',
#   'scoraggiare',
#   'ulteriori',
#   'violazioni',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'da',
#   'parte',
#   'dei',
#   'datori',
#   'di',
#   'lavoro',
#   'o',
#   'dei',
#   'delle',
#   'lavoratori',
#   'trici',
#   'colpevoli',
#   'p',
#   'p',
#   'Lâ',
#   'importo',
#   'della',
#   'pena',
#   'convenzionale',
#   'viene',
#   'stabilito',
#   'applicando',
#   'i',
#   'seguenti',
#   'criteri',
#   'p',
#   'p',
#   'a'],
#  ['entitÃ',
#   'delle',
#   'prestazioni',
#   'in',
#   'denaro',
#   'non',
#   'corrisposte',
#   'dal',
#   'datore',
#   'di',
#   'lavoro',
#   'ai',
#   'alle',
#   'p',
#   'p',
#   'lavoratori',
#   'trici',
#   'ed',
#   'entitÃ',
#   'della',
#   'violazione',
#   'delle',
#   'norme',
#   'sui',
#   'salari',
#   'minimi',
#   'p',
#   'p',
#   'b'],
#  ['violazione',
#   'delle',
#   'disposizioni',
#   'non',
#   'monetarie',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'in',
#   'particolare',
#   'delle',
#   'disposizioni',
#   'sullâ',
#   'orario',
#   'di',
#   'lavoro',
#   'e',
#   'il',
#   'lavoro',
#   'in',
#   'nero',
#   'ai',
#   'sensi',
#   'delle',
#   'disposizioni',
#   'legislative',
#   'e',
#   'contrattuali',
#   'p',
#   'p',
#   'c'],
#  ['violazione',
#   'delle',
#   'singole',
#   'disposizioni',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'unica',
#   'o',
#   'ripetuta',
#   'e',
#   'sua',
#   'gravitÃ',
#   'p',
#   'p',
#   'd'],
#  ['eventuale',
#   'recidiva',
#   'delle',
#   'violazioni',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'p',
#   'p',
#   'e'],
#  ['numero', 'delle', 'violazioni', 'p', 'p', 'f'],
#  ['il',
#   'fatto',
#   'che',
#   'i',
#   'datore',
#   'di',
#   'lavoro',
#   'o',
#   'i',
#   'le',
#   'lavoratori',
#   'trici',
#   'colpevoli',
#   'messo',
#   'in',
#   'mora',
#   'da',
#   'una',
#   'parte',
#   'contrattuale',
#   'abbiano',
#   'giÃ',
#   'adempiuto',
#   'in',
#   'tutto',
#   'o',
#   'in',
#   'parte',
#   'ai',
#   'loro',
#   'obblighi',
#   'p',
#   'p',
#   'g'],
#  ['il',
#   'fatto',
#   'che',
#   'i',
#   'le',
#   'lavoratori',
#   'trici',
#   'facciano',
#   'valere',
#   'individualmente',
#   'i',
#   'loro',
#   'diritti',
#   'nei',
#   'confronti',
#   'di',
#   'un',
#   'datore',
#   'di',
#   'lavoro',
#   'colpevole',
#   'p',
#   'p',
#   'h'],
#  ['In',
#   'caso',
#   'di',
#   'prestazioni',
#   'in',
#   'denaro',
#   'non',
#   'corrisposte',
#   'la',
#   'pena',
#   'convenzionale',
#   'puÃ²',
#   'arrivare',
#   'a',
#   'coprire',
#   'lâ',
#   'importo',
#   'della',
#   'prestazione',
#   'dovuta',
#   'p',
#   'p',
#   '2',
#   'La',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'puÃ²',
#   'disporre',
#   'che',
#   'i',
#   'datori',
#   'di',
#   'lavoro',
#   'o',
#   'i',
#   'le',
#   'lavoratori',
#   'trici',
#   'sottoposti',
#   'ad',
#   'un',
#   'controllo',
#   'dal',
#   'quale',
#   'emerge',
#   'una',
#   'violazione',
#   'degli',
#   'obblighi',
#   'contrattuali',
#   'debbano',
#   'versare',
#   'oltre',
#   'alla',
#   'pena',
#   'convenzionale',
#   'anche',
#   'le',
#   'spese',
#   'di',
#   'controllo',
#   'sostenute',
#   'che',
#   'possono',
#   'essere',
#   'provate',
#   'per',
#   'spese',
#   'sostenute',
#   'sia',
#   'dal',
#   'mandatario',
#   'che',
#   'dalla',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'p',
#   'p',
#   '3',
#   'La',
#   'Commissione',
#   'professionale',
#   'paritetica',
#   'deve',
#   'utilizzare',
#   'gli',
#   'importi',
#   'della',
#   'pena',
#   'convenzionale',
#   'e',
#   'delle',
#   'spese',
#   'di',
#   'controllo',
#   'e',
#   'procedurali',
#   'per',
#   'coprire',
#   'i',
#   'costi',
#   'di',
#   'esecuzione',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'p',
#   'h2',
#   'Il',
#   'Consiglio',
#   'federale',
#   'svizzero',
#   'visto',
#   'lâ',
#   'articolo',
#   '7',
#   'capoverso',
#   '1',
#   'della',
#   'legge',
#   'federale',
#   'del',
#   '28',
#   'settembre',
#   '1956',
#   '1',
#   '2',
#   '3',
#   'concernente',
#   'il',
#   'conferimento',
#   'del',
#   'carattere',
#   'obbligatorio',
#   'generale',
#   'al',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'decreta',
#   'h2',
#   'h3',
#   'Art'],
#  ['1',
#   'h3',
#   'p',
#   'Alle',
#   'allegate',
#   'disposizioni',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'CCL',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'del',
#   '15',
#   'luglio',
#   '2002',
#   'viene',
#   'conferita',
#   'lâ',
#   'obbligatorietÃ',
#   'generale',
#   'p',
#   'h3',
#   'Art'],
#  ['2',
#   'h3',
#   'p',
#   '1',
#   'Lâ',
#   'obbligatorietÃ',
#   'generale',
#   'fa',
#   'stato',
#   'per',
#   'tutto',
#   'il',
#   'territorio',
#   'svizzero',
#   'p',
#   'p',
#   '2',
#   'Le',
#   'disposizione',
#   'del',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'dichiarato',
#   'di',
#   'obbligatorietÃ',
#   'generale',
#   'sono',
#   'applicabili',
#   'ai',
#   'datori',
#   'di',
#   'lavoro',
#   'che',
#   'realizzano',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'a',
#   'base',
#   'di',
#   'cemento',
#   'o',
#   'resine',
#   'sintetiche',
#   'ed',
#   'elementi',
#   'prefabbricati',
#   'in',
#   'calcestruzzo',
#   'e',
#   'ai',
#   'loro',
#   'lavoratori',
#   'indipendentemente',
#   'dal',
#   'tipo',
#   'di',
#   'rimunerazione',
#   'p',
#   'p',
#   'Sono',
#   'eccettuati',
#   'p',
#   'p',
#   'a'],
#  ['i',
#   'lavoratori',
#   'che',
#   'rivestono',
#   'funzioni',
#   'direttive',
#   'p',
#   'p',
#   'b'],
#  ['il', 'personale', 'tecnico', 'p', 'p', 'c'],
#  ['il',
#   'personale',
#   'amministrativo',
#   'p',
#   'p',
#   '3',
#   'Per',
#   'i',
#   'costruttori',
#   'di',
#   'prefabbricati',
#   'apprendisti',
#   'si',
#   'applicano',
#   'le',
#   'disposizioni',
#   'del',
#   'CCL',
#   'elencate',
#   'qui',
#   'di',
#   'seguito',
#   'articoli',
#   '4',
#   'B',
#   'tredicesima',
#   'mensilitÃ',
#   '5',
#   'vacanze',
#   'e',
#   '15',
#   'contributo',
#   'per',
#   'le',
#   'spese',
#   'di',
#   'esecuzione',
#   'p',
#   'h3',
#   'Art'],
#  ['3',
#   'h3',
#   'p',
#   'Per',
#   'quanto',
#   'riguarda',
#   'i',
#   'contributi',
#   'alle',
#   'spese',
#   'dâ',
#   'esecuzione',
#   'art'],
#  ['15',
#   'occorre',
#   'presentare',
#   'annualmente',
#   'alla',
#   'Direzione',
#   'del',
#   'lavoro',
#   'del',
#   'seco',
#   'un',
#   'conteggio',
#   'dettagliato',
#   'nonchÃ',
#   'il',
#   'preventivo',
#   'per',
#   'lâ',
#   'esercizio',
#   'successivo'],
#  ['Il',
#   'conteggio',
#   'va',
#   'corredato',
#   'del',
#   'rapporto',
#   'di',
#   'revisione',
#   'stilato',
#   'da',
#   'un',
#   'ufficio',
#   'riconosciuto'],
#  ['La',
#   'gestione',
#   'delle',
#   'rispettive',
#   'casse',
#   'deve',
#   'essere',
#   'conforme',
#   'alle',
#   'direttive',
#   'stabilite',
#   'dalla',
#   'Direzione',
#   'del',
#   'lavoro',
#   'e',
#   'protrarsi',
#   'oltre',
#   'la',
#   'p',
#   'p',
#   '1',
#   'RS',
#   '221',
#   '215',
#   '311',
#   'p',
#   'h2',
#   'Decreto',
#   'del',
#   'Consiglio',
#   'federale',
#   'che',
#   'conferisce',
#   'obbligatorietÃ',
#   'generale',
#   'al',
#   'contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'h2',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'PAYSCALES_comments_txt',
#   'h2',
#   'Proroga',
#   'e',
#   'modifica',
#   'del',
#   '19',
#   'marzo',
#   '2019',
#   'h2',
#   'div',
#   'p',
#   'b',
#   'III',
#   'b',
#   'p',
#   'p',
#   'Idatori',
#   'di',
#   'lavoro',
#   'che',
#   'hanno',
#   'concesso',
#   'a',
#   'decorrere',
#   'dal',
#   '1Â',
#   'gennaio',
#   '2019',
#   'un',
#   'aumento',
#   'generale',
#   'del',
#   'salario',
#   'possono',
#   'computarlo',
#   'sull',
#   'aumento',
#   'salariale',
#   'conformemente',
#   'allâ',
#   'articolo',
#   '1',
#   'della',
#   'Convenzione',
#   'addizionale',
#   'del',
#   '6',
#   'dicembre',
#   '2018',
#   'p',
#   'p',
#   'b',
#   'IV',
#   'b',
#   'p',
#   'div',
#   'class',
#   'cbaClause',
#   'highlight',
#   'id',
#   'clause',
#   'cbadate_end_date',
#   'p',
#   'II',
#   'presente',
#   'decreto',
#   'entra',
#   'in',
#   'vigore',
#   'il',
#   '1Â',
#   'maggio',
#   '2019',
#   'e',
#   'ha',
#   'effetto',
#   'sino',
#   'al',
#   '31',
#   'dicembre',
#   '2020',
#   'p',
#   'div',
#   'p',
#   '19',
#   'marzo',
#   '2019',
#   'In',
#   'nome',
#   'del',
#   'Consiglio',
#   'federale',
#   'svizzero',
#   'p',
#   'p',
#   'Il',
#   'presidente',
#   'della',
#   'Confederazione',
#   'Ueli',
#   'Maurer',
#   'p',
#   'p',
#   'Il',
#   'cancelliere',
#   'della',
#   'Confederazione',
#   'Walter',
#   'Thurnherr',
#   'p',
#   'p',
#   'b',
#   'Il',
#   'Consiglio',
#   'federale',
#   'svizzero',
#   'decreta',
#   'b',
#   'p',
#   'p',
#   'b',
#   'I',
#   'b',
#   'p',
#   'p',
#   'La',
#   'validitÃ',
#   'dei',
#   'decreti',
#   'del',
#   'Consiglio',
#   'federale',
#   'del',
#   '10',
#   'luglio',
#   '2003',
#   'del',
#   '18',
#   'agosto',
#   '2006',
#   'del',
#   '30',
#   'giugno',
#   '2009',
#   'del',
#   '20',
#   'aprile',
#   '2015',
#   'del',
#   '10',
#   'aprile',
#   '2017',
#   'e',
#   'del',
#   '25',
#   'maggio',
#   '2018',
#   '1',
#   'II',
#   'che',
#   'conferiscono',
#   'obbligatorietÃ',
#   'generale',
#   'al',
#   'Contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'CCL',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'Ã',
#   'prorogata',
#   'fino',
#   'al',
#   '31',
#   'dicembre',
#   '2020',
#   'p',
#   'p',
#   'b',
#   'II',
#   'b',
#   'p',
#   'p',
#   'Le',
#   'disposizioni',
#   'modificate',
#   'qui',
#   'di',
#   'seguito',
#   'menzionate',
#   'nel',
#   'Contratto',
#   'collettivo',
#   'di',
#   'lavoro',
#   'per',
#   'lâ',
#   'industria',
#   'svizzera',
#   'dei',
#   'prodotti',
#   'in',
#   'calcestruzzo',
#   'allegato',
#   'ai',
#   'decreti',
#   'del',
#   'Consiglio',
#   'federale',
#   'menzionati',
#   'alla',
#   'cifra',
#   'I',
#   'sono',
#   'dichiarate',
#   'd',
#   'obbligatorietÃ',
#   'generale',
#   'p',
#   'p',
#   'Convenzione',
#   'addizionale',
#   'del',
#   '6',
#   'dicembre',
#   '2018',
#   'p',
#   'h3',
#   'Art'],
#  ['1',
#   'Adeguamenti',
#   'salariali',
#   'generali',
#   'e',
#   'individuali',
#   'h3',
#   'p',
#   '1',
#   'Adeguamento',
#   'generale',
#   'dei',
#   'salari',
#   'effettivi',
#   '35',
#   'franchi',
#   'al',
#   'mese',
#   'p',
#   'p',
#   '2',
#   'Adeguamento',
#   'individuale',
#   'dei',
#   'salari',
#   'la',
#   'massa',
#   'salariale',
#   'dei',
#   'delle',
#   'lavoratori',
#   'trici',
#   'sottoposti',
#   'e',
#   'al',
#   'CCL',
#   'deve',
#   'aumentare',
#   'mediamente',
#   'di',
#   '10',
#   'franchi',
#   'al',
#   'mese',
#   'p',
#   'p',
#   '1',
#   'FF',
#   '2003',
#   '4473',
#   '2006',
#   '6205',
#   '2009',
#   '4475',
#   '2015',
#   '2835',
#   '2017',
#   '2909',
#   '2018',
#   '2849',
#   'p',
#   'p',
#   'p']]

# %%
## Remove punctuation - keep only alphabetical characters

no_punct = []
for index, row in df.iterrows():
  text = list(chain.from_iterable(row['tokenized']))
  npun = [word for word in text if word.isalpha()]
  no_punct.append(npun)

df['no_punct'] = no_punct

# Check one text  
df['no_punct'][10]
# Out:
# ['xml',
#  'version',
#  'encoding',
#  'UTF',
#  'meta',
#  'http',
#  'equiv',
#  'content',
#  'type',
#  'content',
#  'text',
#  'html',
#  'charset',
#  'UTF',
#  'title',
#  'calcestruzzo',
#  'title',
#  'meta',
#  'name',
#  'generator',
#  'content',
#  'Amaya',
#  'see',
#  'http',
#  'www',
#  'org',
#  'Amaya',
#  'Contratto',
#  'collettivo',
#  'di',
#  'lavoro',
#  'per',
#  'lâ',
#  'industria',
#  'svizzera',
#  'dei',
#  'prodotti',
#  'in',
#  'calcestruzzo',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'cbaratified',
#  'Decreto',
#  'del',
#  'Consiglio',
#  'federale',
#  'che',
#  'conferisce',
#  'obbligatorietÃ',
#  'generale',
#  'al',
#  'contratto',
#  'collettivo',
#  'di',
#  'lavoro',
#  'per',
#  'lâ',
#  'industria',
#  'svizzera',
#  'dei',
#  'prodotti',
#  'in',
#  'calcestruzzo',
#  'del',
#  'luglio',
#  'div',
#  'p',
#  'fine',
#  'del',
#  'contratto',
#  'collettivo',
#  'di',
#  'lavoro',
#  'quanto',
#  'lo',
#  'richieda',
#  'il',
#  'disbrigo',
#  'delle',
#  'pendenze',
#  'o',
#  'di',
#  'altri',
#  'avvenimenti',
#  'che',
#  'rientrano',
#  'nella',
#  'durata',
#  'di',
#  'validitÃ',
#  'del',
#  'contratto',
#  'collettivo',
#  'di',
#  'lavoro',
#  'La',
#  'Direzione',
#  'del',
#  'lavoro',
#  'inoltre',
#  'chiedere',
#  'per',
#  'visione',
#  'altri',
#  'documenti',
#  'e',
#  'informazioni',
#  'e',
#  'far',
#  'eseguire',
#  'controlli',
#  'a',
#  'carico',
#  'delle',
#  'parti',
#  'contraenti',
#  'p',
#  'Art',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'p',
#  'Il',
#  'presente',
#  'decreto',
#  'entro',
#  'in',
#  'vigore',
#  'il',
#  'agosto',
#  'ed',
#  'Ã',
#  'valido',
#  'sino',
#  'al',
#  'dicembre',
#  'p',
#  'div',
#  'p',
#  'luglio',
#  'In',
#  'nome',
#  'del',
#  'Consiglio',
#  'federale',
#  'svizzero',
#  'p',
#  'p',
#  'Il',
#  'presidente',
#  'della',
#  'Confederazione',
#  'Pascal',
#  'Couchepin',
#  'p',
#  'p',
#  'La',
#  'cancelliera',
#  'della',
#  'Confederazione',
#  'Annemarie',
#  'Huber',
#  'Hotz',
#  'p',
#  'Appendice',
#  'Contratto',
#  'collettivo',
#  'di',
#  'lavoro',
#  'per',
#  'lâ',
#  'industria',
#  'svizzera',
#  'dei',
#  'prodotti',
#  'in',
#  'calcestruzzo',
#  'concluso',
#  'il',
#  'luglio',
#  'p',
#  'tra',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'p',
#  'Swiss',
#  'Beton',
#  'e',
#  'lâ',
#  'Union',
#  'des',
#  'fabricants',
#  'de',
#  'produits',
#  'en',
#  'bÃ',
#  'ton',
#  'de',
#  'Suisse',
#  'Romande',
#  'da',
#  'una',
#  'parte',
#  'p',
#  'div',
#  'div',
#  'div',
#  'p',
#  'e',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'p',
#  'il',
#  'Sindacato',
#  'Edilizia',
#  'amp',
#  'Industria',
#  'e',
#  'il',
#  'Sindacato',
#  'SYNA',
#  'dallâ',
#  'altra',
#  'parte',
#  'p',
#  'div',
#  'Disposizioni',
#  'dichiarate',
#  'dâ',
#  'obbligatorietÃ',
#  'generale',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'hourstxt',
#  'Art',
#  'Orario',
#  'di',
#  'lavoro',
#  'div',
#  'p',
#  'Il',
#  'normale',
#  'orario',
#  'di',
#  'lavoro',
#  'settimanale',
#  'Ã',
#  'di',
#  'ore',
#  'Per',
#  'i',
#  'lavori',
#  'a',
#  'turno',
#  'fa',
#  'stato',
#  'il',
#  'piano',
#  'dei',
#  'turni',
#  'approvato',
#  'dalle',
#  'autoritÃ',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'overtimeallowancetxt',
#  'p',
#  'La',
#  'ripartizione',
#  'delle',
#  'ore',
#  'di',
#  'lavoro',
#  'sui',
#  'giorni',
#  'della',
#  'settimana',
#  'viene',
#  'fissata',
#  'dal',
#  'datore',
#  'di',
#  'lavoro',
#  'previa',
#  'consultazione',
#  'con',
#  'la',
#  'commissione',
#  'di',
#  'fabbrica',
#  'o',
#  'con',
#  'i',
#  'le',
#  'lavorato',
#  'ri',
#  'trici',
#  'Il',
#  'datore',
#  'di',
#  'lavoro',
#  'Ã',
#  'libero',
#  'di',
#  'ripartire',
#  'il',
#  'lavoro',
#  'sullâ',
#  'arco',
#  'dellâ',
#  'intero',
#  'anno',
#  'in',
#  'modo',
#  'che',
#  'la',
#  'settimana',
#  'lavorativa',
#  'media',
#  'corrisponda',
#  'a',
#  'ore',
#  'p',
#  'div',
#  'p',
#  'p',
#  'p',
#  'Se',
#  'a',
#  'causa',
#  'di',
#  'guasti',
#  'o',
#  'problemi',
#  'nella',
#  'produzione',
#  'o',
#  'per',
#  'altri',
#  'motivi',
#  'il',
#  'lavoro',
#  'viene',
#  'interrotto',
#  'per',
#  'un',
#  'periodo',
#  'relativamente',
#  'breve',
#  'o',
#  'nel',
#  'caso',
#  'in',
#  'cui',
#  'al',
#  'la',
#  'lavoratore',
#  'trice',
#  'vengono',
#  'concesse',
#  'giornate',
#  'libere',
#  'dietro',
#  'sua',
#  'richiesta',
#  'in',
#  'deroga',
#  'allâ',
#  'orario',
#  'di',
#  'lavoro',
#  'settimanale',
#  'massimo',
#  'il',
#  'datore',
#  'di',
#  'lavoro',
#  'esigere',
#  'ai',
#  'sensi',
#  'della',
#  'legge',
#  'sul',
#  'lavoro',
#  'una',
#  'compensazione',
#  'delle',
#  'ore',
#  'lavorative',
#  'entro',
#  'un',
#  'periodo',
#  'di',
#  'settimane',
#  'p',
#  'p',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'schedulestxt',
#  'p',
#  'Il',
#  'sabato',
#  'di',
#  'regola',
#  'non',
#  'si',
#  'lavora',
#  'p',
#  'div',
#  'p',
#  'Nelle',
#  'giornate',
#  'libere',
#  'possono',
#  'essere',
#  'svolte',
#  'attivitÃ',
#  'lavorative',
#  'a',
#  'scopo',
#  'di',
#  'lucro',
#  'solo',
#  'con',
#  'il',
#  'consenso',
#  'del',
#  'datore',
#  'di',
#  'lavoro',
#  'p',
#  'p',
#  'p',
#  'p',
#  'Di',
#  'comune',
#  'accordo',
#  'con',
#  'il',
#  'la',
#  'lavoratore',
#  'trice',
#  'il',
#  'datore',
#  'di',
#  'lavoro',
#  'compensare',
#  'entro',
#  'otto',
#  'settimane',
#  'il',
#  'lavoro',
#  'straordinario',
#  'con',
#  'tempo',
#  'libero',
#  'che',
#  'abbia',
#  'almeno',
#  'la',
#  'stessa',
#  'durata',
#  'Se',
#  'il',
#  'lavoro',
#  'straordinario',
#  'viene',
#  'compensato',
#  'con',
#  'tempo',
#  'libero',
#  'il',
#  'datore',
#  'di',
#  'lavoro',
#  'scegliere',
#  'se',
#  'compensare',
#  'il',
#  'supplemento',
#  'con',
#  'denaro',
#  'o',
#  'tempo',
#  'libero',
#  'Se',
#  'il',
#  'lavoro',
#  'straordinario',
#  'non',
#  'viene',
#  'compensato',
#  'con',
#  'tempo',
#  'libero',
#  'il',
#  'datore',
#  'di',
#  'lavoro',
#  'Ã',
#  'tenuto',
#  'a',
#  'corrispondere',
#  'un',
#  'supplemento',
#  'del',
#  'Per',
#  'il',
#  'lavoro',
#  'straordinario',
#  'eseguito',
#  'la',
#  'domenica',
#  'o',
#  'nei',
#  'giorni',
#  'festivi',
#  'il',
#  'supplemento',
#  'Ã',
#  'pari',
#  'al',
#  'p',
#  'p',
#  'Restano',
#  'escluse',
#  'le',
#  'disposizioni',
#  'per',
#  'lâ',
#  'indennitÃ',
#  'del',
#  'lavoro',
#  'a',
#  'turni',
#  'p',
#  'p',
#  'Nei',
#  'giorni',
#  'festivi',
#  'soggetti',
#  'ad',
#  'indennitÃ',
#  'al',
#  'la',
#  'lavoratore',
#  'trice',
#  'viene',
#  'corrisposto',
#  'il',
#  'salario',
#  'con',
#  'il',
#  'relativo',
#  'supplemento',
#  'Tali',
#  'giorni',
#  'festivi',
#  'devono',
#  'essere',
#  'compensati',
#  'con',
#  'un',
#  'altro',
#  'giorno',
#  'di',
#  'tempo',
#  'libero',
#  'oppure',
#  'devono',
#  'essere',
#  'indennizzati',
#  'quali',
#  'giorni',
#  'festivi',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'Art',
#  'Salario',
#  'p',
#  'Ai',
#  'alle',
#  'lavoratori',
#  'trici',
#  'viene',
#  'corrisposto',
#  'un',
#  'salario',
#  'mensile',
#  'La',
#  'base',
#  'di',
#  'calcolo',
#  'Ã',
#  'data',
#  'da',
#  'ore',
#  'mensili',
#  'p',
#  'div',
#  'p',
#  'p',
#  'p',
#  'b',
#  'A',
#  'Salari',
#  'minimi',
#  'b',
#  'p',
#  'p',
#  'Per',
#  'i',
#  'le',
#  'lavoratori',
#  'lavoratrici',
#  'pienamente',
#  'abili',
#  'al',
#  'lavoro',
#  'con',
#  'di',
#  'anni',
#  'i',
#  'salari',
#  'minimi',
#  'concordati',
#  'ammontano',
#  'a',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'div',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'div',
#  'div',
#  'table',
#  'border',
#  'caption',
#  'caption',
#  'colgroup',
#  'col',
#  'col',
#  'colgroup',
#  'tbody',
#  'tr',
#  'tr',
#  'tr',
#  'tr',
#  'tr',
#  'td',
#  'lavoratori',
#  'trici',
#  'non',
#  'qualificati',
#  'e',
#  'td',
#  'td',
#  'fr',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'lavoratori',
#  'trici',
#  'semiqualificati',
#  'e',
#  'td',
#  'td',
#  'fr',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'lavoratori',
#  'trici',
#  'qualificati',
#  'e',
#  'td',
#  'td',
#  'fr',
#  'td',
#  'tr',
#  'tr',
#  'tr',
#  'tr',
#  'tr',
#  'tbody',
#  'table',
#  'p',
#  'In',
#  'caso',
#  'di',
#  'nuova',
#  'assunzione',
#  'nel',
#  'primo',
#  'anno',
#  'di',
#  'servizio',
#  'il',
#  'salario',
#  'essere',
#  'ridotto',
#  'di',
#  'fr',
#  'p',
#  'p',
#  'p',
#  'p',
#  'b',
#  'B',
#  'Tredicesima',
#  'mensilitÃ',
#  'b',
#  'p',
#  'p',
#  'Alla',
#  'fine',
#  'dellâ',
#  'anno',
#  'civile',
#  'i',
#  'lavoratori',
#  'e',
#  'le',
#  'lavoratrici',
#  'hanno',
#  'diritto',
#  'ad',
#  'una',
#  'tredicesima',
#  'mensilitÃ',
#  'pari',
#  'allâ',
#  'del',
#  'salario',
#  'totale',
#  'percepito',
#  'nelIâ',
#  'anno',
#  'civile',
#  'in',
#  'oggetto',
#  'senza',
#  'supplementi',
#  'o',
#  'compensi',
#  'per',
#  'lavoro',
#  'straordinario',
#  'Anche',
#  'la',
#  'tredicesima',
#  'mensilitÃ',
#  'deve',
#  'rientrare',
#  'nellâ',
#  'assicurazione',
#  'di',
#  'indennitÃ',
#  'giornaliera',
#  'di',
#  'malattia',
#  'p',
#  'p',
#  'Il',
#  'datore',
#  'di',
#  'lavoro',
#  'Ã',
#  'autorizzato',
#  'a',
#  'computare',
#  'gratifiche',
#  'o',
#  'altre',
#  'prestazioni',
#  'supplementari',
#  'di',
#  'fine',
#  'anno',
#  'con',
#  'la',
#  'tredicesima',
#  'mensilitÃ',
#  'p',
#  'p',
#  'Anche',
#  'le',
#  'apprendiste',
#  'e',
#  'gli',
#  'apprendisti',
#  'hanno',
#  'diritto',
#  'a',
#  'percepire',
#  'la',
#  'tredicesima',
#  'mensilitÃ',
#  'p',
#  'p',
#  'b',
#  'C',
#  'Lavoro',
#  'a',
#  'turni',
#  'b',
#  'p',
#  'p',
#  'Per',
#  'le',
#  'aziende',
#  'che',
#  'adottano',
#  'lâ',
#  'orario',
#  'di',
#  'lavoro',
#  'a',
#  'due',
#  'turni',
#  'il',
#  'supplemento',
#  'ammonta',
#  'a',
#  'fr',
#  'allâ',
#  'ora',
#  'p',
#  'p',
#  'p',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'Art',
#  'Vacanze',
#  'div',
#  'p',
#  'Diritto',
#  'p',
#  'table',
#  'border',
#  'caption',
#  'caption',
#  'colgroup',
#  'col',
#  'col',
#  'col',
#  'col',
#  'colgroup',
#  'tbody',
#  'tr',
#  'td',
#  'td',
#  'tr',
#  'tbody',
#  'table',
#  'div',
#  'class',
#  'cbaClause',
#  'highlight',
#  'id',
#  'clause',
#  'holidaystxt',
#  'table',
#  'border',
#  'tbody',
#  'tr',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'a',
#  'partire',
#  'dal',
#  'Â',
#  'anno',
#  'di',
#  'servizio',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'giorni',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'dopo',
#  'anni',
#  'di',
#  'servizio',
#  'nellâ',
#  'azienda',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'giorni',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'dopo',
#  'il',
#  'compimento',
#  'del',
#  'anno',
#  'di',
#  'etÃ',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'td',
#  'giorni',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'fino',
#  ...]

# %%
## Make lowercase
lowercase = []
for index, row in df.iterrows():
  text = row['no_punct']
  lc = [w.lower() for w in text]
  lowercase.append(lc)

df['lowercase'] = lowercase

# %% [markdown]
# ## Subdividing by language

# %%
def make_list(lang, df):
  texts = df['lowercase'][(df['language'] == lang)]
  text = pd.DataFrame(texts)
  text_list = text['lowercase'].tolist() # Save the dataframe column as a list of lists
  text = [[re.sub("[ '\"]", "",article) for article in x] for x in text_list]
  return text

# %%
all_texts = {}
for language in df['language'].unique():
  all_texts["%s" %language] = make_list(language, df)

# %%
len(all_texts['NL'][1])
# Out:
# 56051

# %% [markdown]
# ## Build embedding spaces

# %%
import multiprocessing

cores = multiprocessing.cpu_count() # Count the number of cores in a computer

cores
# Out:
# 2

# %%
for key,text in zip(all_texts.keys(),all_texts.values()):
  print(len(text),key)
# Out:
# 138 FR
# 414 EN
# 14 DA
# 3 MT
# 11 DE
# 5 SL
# 1 LT
# 15 SV
# 25 TR
# 86 IT
# 3 FI
# 1 BG
# 8 SK
# 3 CS
# 94 PT
# 102 NL
# 8 EL
# 24 RO
# 6 HR
# 256 ES
# 10 HU
# 4 ET
# 10 PL
# 5 KM
# 5 VI
# 176 BA
# 12 AM
# 1 SR

# %%
# Parameters
m_count = 10  #10 20 30 minimum count: Ignores all words with a lower total absolute frequency
window = 5#the maximum distance between current and predicted word within a sentence
s = 300       #100 300 dimensionality of the feature vectors
model_type = 1 # 0:CBOW 1:skip-gram
sample = 0 # threshold to configure which high-frequency words are randomly downsampled
alpha = 0.05 #initial learning rate
epochs = 10
min_alpha = alpha/epochs #Learning rate will linearly drop to min_alpha as training progresses. set: alpha - (min_alpha * epochs) ~ 0.00
negative = 10 #If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. 
              #If set to 0, no negative sampling is used. - (5, 20)
workers = cores #how many workers train the model
seed = 2


# Train and save embeddings
for lan, text in zip(all_texts.keys(),all_texts.values()):
  # set parameters in model
  model = Word2Vec(min_count = m_count,
                   window=window, 
                   size=s,
                   alpha=alpha,
                   sg=model_type, 
                   min_alpha=min_alpha,  
                   negative=negative, 
                   seed = seed,
                   workers = workers) 
  
  file_name = lan
  
  # Build vocabulary table
  model.build_vocab(text, progress_per=10000)
  
  # Train model
  model.train(text, total_examples=model.corpus_count, epochs=epochs,report_delay=2)
  
  # Summarize model
  print(model)

  # Summarize vocabulary
  words = list(model.wv.vocab)
  print("\nVocabulary (first 50): \n", words[:50])

  # Save model
  model_path = '/content/drive/My Drive/dhh21/models/'

  word_vectors = model.wv

  word_vectors.save(model_path+file_name+"_word2vec.wordvectors") #Store just the words + their trained embeddings.
  model.save(model_path+file_name+"_word2vec.model") #saving the whole model

  # Load back with memory-mapping = read-only, shared across processes.
  #wv = KeyedVectors.load(model_path+file_name+"_word2vec.wordvectors", mmap='r')
# Out:
# Word2Vec(vocab=8633, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'contratto', 'collettivo', 'di', 'lavoro', 'dei', 'laboratori', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'decreto', 'del', 'consiglio', 'federale', 'che', 'conferisce', 'obbligatorietã', 'generale', 'al', 'svizzeri', 'aprile', 'art', 'p', 'il', 'presente', 'entro', 'in', 'vigore', 'giugno']
# Word2Vec(vocab=6331, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'utf', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'european', 'appendix', 'to', 'abb', 'group', 'social', 'policy', 'preamble', 'p', 'in', 'addition', 'groupâ', 's', 'which', 'is', 'wholly', 'supported', 'by', 'the', 'employees', 'council', 'europe', 'following', 'also', 'applies', 'specifically', 'companies', 'and', 'covered', 'this', 'must', 'be', 'applied', 'on']
# Word2Vec(vocab=2340, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['version', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'aftale', 'mellem', 'kl', 'og', 'forhandlingsfã', 'llesskabet', 'om', 'overenskomst', 'pr', 'april', 'p', 'tid', 'den', 'sted', 'kã', 'benhavn', 'reprã', 'sentanter', 'for', 'protokollat', 'der', 'er', 'enighed', 'at', 'overenskomster', 'aftaler', 'inden', 'det', 'kommunale', 'omrã', 'de', 'perioden', 'â']
# Word2Vec(vocab=744, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'text', 'ftehim', 'kollettiv', 'bejn', 'farsons', 'it', 'taqsima', 'ikel', 'u', 'xorb', 'tal', 'union', 'ä', 'addiema', 'magä', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'p', 'mel', 'l', 'tax', 'xogä', 'ol', 'tiegä', 'gä', 'al', 'sä', 'la', 'li', 'aq', 'taâ', 'jannar', 't', 'h', 'm', 'reä', 'uffiä', 'skond', 'att', 'tat', 'malta', 'dwar', 'industrijali', 'fid', 'data']
# Word2Vec(vocab=1209, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'p', 'rahmen', 'kollektivvertrag', 'artikel', 'i', 'vertragspartner', 'ii', 'geltungsbereich', 'iii', 'geltungsdauer', 'und', 'allgemeine', 'bestimmungen', 'iv', 'grundsã', 'v', 'pflichten', 'des', 'dienstnehmers', 'vi', 'arbeitszeit', 'vii', 'ã', 'berstunden', 'sonn', 'feiertagsarbeit', 'ix']
# Word2Vec(vocab=919, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'content', 'text', 'title', 'amaya', 'p', 'pogodbeni', 'stranki', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'sindikat', 'delavcev', 'trgovine', 'slovenije', 'â', 'na', 'strani', 'in', 'zbornica', 'delodajalcev', 'ter', 'podlagi', 'doloä', 'b', 'zakona', 'o', 'delovnih', 'razmerjih', 'uradni', 'list', 'rs', 'å', 't', 'kolektivnih', 's', 'kolektivno', 'pogodbo', 'dejavnosti', 'i', 'sploå', 'ne', 'be', 'ä', 'len', 'veljavnost']
# Word2Vec(vocab=53, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['kolektyvinä', 'sutartis', 'dä', 'l', 's', 'sutarties', 'p', 'pagal', 'ä', 'ir', 'yra', 'bendrovä', 'â', 'darbdavys', 'profesinä', 'sä', 'junga', 'jungos', 'å', 'o', 'sutartä', 'iå', 'teisä', 'darbo', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'darbuotojams', 'nuo', 'je', 'bå', 'su', 'per', 'iki', 'mä', 'kaip', 'darbdavio', 'tvarka', 'bei', 'nustatyta', 'darbuotojo', 'ti', 'raå', 'turi', 'ar', 'gali', 'skaiä']
# Word2Vec(vocab=2190, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'p', 'kompetensfã', 'retagen', 'f', 'd', 'bemanningsfã', 'â', 'fã', 'rteckning', 'ã', 'ver', 'sã', 'rskilda', 'verenskommelser', 'som', 'ej', 'tagits', 'med', 'i', 'arbetsmiljã', 'avtalet', 'tjã', 'itp', 'collectum', 'avtal', 'om', 'nstegrupplivfã', 'rsã', 'kring', 'tgl', 'nã']
# Word2Vec(vocab=1914, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'tedaå', 'tã', 'rkä', 'ye', 'elekträ', 'k', 'daä', 'itim', 'a', 'å', 'genel', 'mã', 'dã', 'rlã', 'ä', 'ã', 've', 'baä', 'li', 'n', 'p', 'nem', 'letme', 'toplu', 'sã', 'zleå', 'mesä', 'mza', 'tarihi', 'i', 'bã']
# Word2Vec(vocab=9177, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'utf', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'enel', 'global', 'framework', 'roma', 'giugno', 'p', 'tra', 's', 'a', 'anche', 'in', 'rappresentanza', 'di', 'tutte', 'le', 'societã', 'del', 'gruppo', 'rappresentata', 'dai', 'sigg', 'e', 'filctem', 'cgil', 'cisl', 'de', 'uiltec', 'uil']
# Word2Vec(vocab=395, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['type', 'align', 'center', 'br', 'clear', 'all', 'div', 'class', 'cbaclause', 'id', 'clause', 'kaupan', 'tyã', 'ja', 'strong', 'â', 'sopimuksen', 'ol', 'li', 'sopimusta', 'noudatetaan', 'yrityksessã', 'jonka', 'on', 'a', 'vã', 'huolto', 'sopimus', 'koskee', 'aikalain', 'ntekijã', 'itã', 'suhde', 'nantaja', 'tã', 't', 'mã', 'ã', 'rã', 'hã', 'n', 'tai', 'siihen', 'jã', 'rjestã', 'highlight', 'sopimuksessa', 'tulee', 'olla', 's']
# Word2Vec(vocab=17, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['ð', 'p', 'ñ', 'ðµ', 'ðºð', 'ðµðºñ', 'ðµð', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'ðµñ', 'ðºñ', 'â', 'ðº']
# Word2Vec(vocab=926, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['utf', 'meta', 'http', 'content', 'html', 'title', 'name', 'amaya', 'p', 'v', 'bratislave', 'rada', 'zã', 'kladnã', 'ch', 'organizã', 'ciã', 'odborovã', 'ho', 'zvã', 'zu', 'pracovnã', 'kov', 'å', 'a', 'kolektã', 'vna', 'zmluva', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'bratislava', 'k', 'o', 'l', 'e', 't', 'ã', 'n', 'z', 'm', 'u', 'medzi', 'na', 'tã', 'to', 'je']
# Word2Vec(vocab=330, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['http', 'title', 'www', 'p', 'v', 'souladu', 's', 'på', 'ã', 'sluå', 'ustanovenã', 'mi', 'zã', 'kona', 'ä', 'sb', 'konã', 'ku', 'prã', 'ce', 'dã', 'le', 'jen', 'â', 'k', 'i', 'a', 'o', 'kolektivnã', 'm', 'vyjednã', 'vã', 'nã', 'smluvnã', 'strany', 'penny', 'market', 'r', 'se', 'sã', 'poä', 'spoleä', 'nosti', 'iä', 'zamä', 'stnavatel', 'na', 'stranä', 'jednã', 'kladnã']
# Word2Vec(vocab=5838, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'acordo', 'ren', 'novo', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'coletivo', 'entre', 'a', 'redes', 'energã', 'ticas', 'nacionais', 'sgps', 'sa', 'e', 'outras', 'federaã', 'ã', 'o', 'intersindical', 'das', 'indãºstrias', 'metalãºrgicas', 'quã', 'micas', 'elã', 'ctricas']
# Word2Vec(vocab=9930, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['doctype', 'html', 'public', 'dtd', 'transitional', 'en', 'http', 'www', 'org', 'tr', 'loose', 'xmlns', 'xhtml', 'head', 'meta', 'equiv', 'content', 'type', 'text', 'charset', 'utf', 'title', 'name', 'generator', 'amaya', 'see', 'body', 'p', 'collectieve', 'arbeidsovereenkomst', 'voor', 'de', 'groothandel', 'in', 'bouwmaterialen', 'looptijd', 'januari', 't', 'm', 'december', 'cao', 'secretariaat', 'll', 'ede', 'info', 'hibin', 'nl', 'toelichting', 'deze', 'is']
# Word2Vec(vocab=68, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'content', 'text', 'title', 'î', 'ï', 'îºî', 'îµï', 'îµî', 'p', 'â', 'îµîºï', 'îºîµï', 'îºï', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'table', 'border', 'cellspacing', 'cellpadding', 'style', 'margin', 'left', 'tbody', 'tr', 'height', 'td', 'width', 'colspan', 'valign', 'top', 'solid', 'windowtext', 'bottom', 'none', 'right', 'background', 'white', 'padding', 'align', 'center', 'indent', 'line', 'transparent', 'span']
# Word2Vec(vocab=3620, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'contract', 'colective', 'de', 'la', 'nivelul', 'universitä', 'è', 'ii', 'â', 'alexandru', 'ioan', 'cuzaâ', 'iaè', 'i', 'pe', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'p', 'ã', 'nregistrat', 'universitate', 'sub', 'nr', 'itm', 'b', 'pä', 'rè']
# Word2Vec(vocab=931, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'content', 'utf', 'title', 'amaya', 'e', 'l', 'i', 'o', 'v', 'u', 'g', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'za', 'radnike', 'trgovaä', 'kim', 'druå', 'tvu', 'grada', 'zagreba', 'p', 'zagreb', 'a', 'odredbe', 'ä', 'lanak', 'ovim', 'kolektivnim', 'ugovorom', 'daljnjem', 'tekstu', 'ugovor', 'ureä', 'uju', 'se', 'prava', 'obveze', 'ugovornih', 'te', 'pravila', 'kojima', 'uje', 'sklapanje']
# Word2Vec(vocab=9757, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'utf', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'trainingprogrammes', 'trainingfund', 'acuerdo', 'estatal', 'de', 'profesional', 'para', 'el', 'empleo', 'en', 'marco', 'del', 'sector', 'la', 'economã', 'a', 'y', 'industria', 'digital', 'n', 'estructura', 'paritaria', 'sectorial', 'p', 'iii', 'otras', 'disposiciones', 'ministerio']
# Word2Vec(vocab=1501, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'ã', 'pã', 'tå', 'ipari', 'gazati', 'kollektã', 'v', 'szerzå', 'dã', 's', 'p', 'a', 'sz', 'tã', 'ssal', 'egysã', 'ges', 'szerkezetbe', 'szã', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'budapest', 'februã', 'r', 'az', 'tovã', 'bbiakban', 'ksz', 'st']
# Word2Vec(vocab=239, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['content', 'new', 'kollektiivleping', 'p', 'kã', 'esoleva', 'kollektiivlepingu', 'edaspidi', 'leping', 'loetakse', 'as', 'prisma', 'peremarket', 'tã', 'ã', 'andja', 'vãµi', 'â', 'a', 'd', 'seaduse', 'ja', 'alusel', 'ning', 'eesti', 'tajate', 'sãµlmitud', 'liikmete', 'tajad', 'pooled', 'lepingu', 'etka', 'lã', 'kui', 'suhetes', 'taja', 'ei', 'tema', 'mis', 'nende', 'tingimusi', 'ãµigus', 'on', 'kohustatud', 'tajaid', 'selle', 'koos', 'usaldusisiku', 'te', 'kohta']
# Word2Vec(vocab=1757, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'utf', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'zakå', 'adowy', 'ukå', 'ad', 'zbiorowy', 'pracy', 'w', 'skanska', 'ka', 'warszawie', 'p', 'zawarty', 'pomiä', 'dzy', 'div', 'class', 'cbaclause', 'highlight', 'id', 'clause', 'z', 'siedzibä', 'ul', 'zajä', 'przez', 'prezesa', 'zarzä', 'du', 'a', 'organizacjä', 'miä', 'dzyzakå', 'adowä', 'samorzä']
# Word2Vec(vocab=168, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['á', 'agreement', 'between', 'sunway', 'hotel', 'management', 'and', 'employees', 'union', 'p', 'for', 'years', 'ºá', 'â', 'lt', 'gt', 'f', 'amp', 'b', 'º', 'ªá', 'general', 'manager', 'president', 'human', 'secretary', 'advisor', 'collective', 'bargaining', 'of', 'employee', 'the', 'is', 'written', 'employer', 'a', 'it', 'made', 'to', 'working', 'law', 'discipline', 'work', 'this', 'in', 'other', 'any', 'provide', 'benefits', 'parties']
# Word2Vec(vocab=228, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['meta', 'http', 'content', 'title', 'amaya', 'thoáº', 'æ', 'á', 'c', 'lao', 'ä', 'ã', 'ng', 'táº', 'p', 'thá', 'nhã', 'mã', 'y', 'tinh', 'bá', 't', 'sáº', 'n', 'sæ', 'cá', 'hoã', 'xã', 'há', 'i', 'chá', 'nghä', 'a', 'viá', 'nam', 'lá', 'tá', 'do', 'háº', 'nh', 'phãºc', 'ngã', 'thã', 'nä', 'm', 'cä', 'luáº', 'næ', 'vã', 'sá']
# Word2Vec(vocab=4621, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['xml', 'version', 'encoding', 'utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'title', 'name', 'generator', 'amaya', 'see', 'www', 'org', 'kesepakatan', 'bersama', 'antara', 'pengusaha', 'dan', 'serikat', 'pekerja', 'nasional', 'pt', 'tentang', 'perjanjian', 'kerja', 'periode', 'tahun', 'p', 'mukadimah', 'style', 'align', 'justify', 'dengan', 'menyadari', 'bahwa', 'untuk', 'menciptakan', 'ketenangan', 'bekerja', 'bagi', 'berusaha', 'perlu', 'adanya', 'hubungan']
# Word2Vec(vocab=371, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['utf', 'meta', 'http', 'equiv', 'content', 'type', 'text', 'html', 'charset', 'www', 'org', 'waldaa', 'itti', 'isaa', 'murtaaâ', 'ee', 'fi', 'buâ', 'hojjattoota', 'waltaâ', 'iinsa', 'gamtaa', 'p', 'eegalee', 'hanga', 'walta', 'walitti', 'hojjachiisaa', 'hojjataan', 'qabu', 'haala', 'mindaa', 'keenna', 'sadarkaa', 'adda', 'addaa', 'u', 'omishaa', 'hojjataa', 'akka', 'ilaalchisee', 'uura', 'labsii', 'dhimma', 'kan', 'irra', 'irratti', 'hin', 'dirqama', 'hojii']
# Word2Vec(vocab=19, size=300, alpha=0.05)
#
# Vocabulary (first 50):
#  ['tr', 'p', 'ð', 'ñ', 'ðµñ', 'ðµð', 'ðºñ', 'ðºð', 'ðµðºñ', 'â', 'ðº', 'ðµ', 'ðµâ', 'i', 'ii', 'ðµðºð', 'ðºðµ', 'td', 'rowspan']

# %% [markdown]
# ## Semantic neighborhood density

# %%
# Load wordvectors
from gensim.models import word2vec
from gensim.models import KeyedVectors
from google.colab import drive
import numpy as np
from numpy import dot
from numpy.linalg import norm
from gensim.models import Word2Vec
import pandas as pd
import random


seed = 24

model_path = "/content/drive/My Drive/dhh21/models/"
extension = "_word2vec.wordvectors"

all_models = {}
for language in df['language'].unique():
  all_models["%s" %language] = KeyedVectors.load(model_path+language+extension, mmap='r')

# %%
all_models["EN"].wv.similarity("worker", "employee")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# 0.40750203

# %%
# Create a dictionary of dictionaries: for each language, every word in the vocabulary gets a SND score
all_snd = {}
for language in df['language'].unique(): # Language loop

  vectors = all_models[language]
  vocabulary = vectors.vocab
  
  sdn = {}
  for word in vocabulary: # for each word in the vocabulary of a language
    top10 = vectors.wv.most_similar(positive=word) # Return the top 10 nearest neighbord
    cos_scores = [x[1] for x in top10] # Save the cosine similarity scores of these 10 neighbors
    avg = sum(cos_scores)/len(cos_scores) # Calculate the semantic neighborhood density: average of the 10 nearest neighbors cosine similarity score
    sdn[word] = avg # Save the word and its SND score as a key-value combination
  all_snd["%s" %language] = sdn # Save the dictionary of SND scores in a dictionary per language
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Get the words scoring <0.1 and >0.9

low_high = {}
for language in df['language'].unique():
  d = {}
  for (key, value) in all_snd[language].items():
    if value > 0.9:
      d["%s" %key] = value
    elif value < 0.15:
      d["%s" %key] = value
  low_high["%s" %language] = d

# %%
low_high["IT"]
# Out:
# {'acute': 0.14214195013046266,
#  'adolfo': 0.907177472114563,
#  'ag': 0.9196115434169769,
#  'aldo': 0.9217536270618438,
#  'alessandra': 0.9100626349449158,
#  'alessio': 0.9141308248043061,
#  'alfonso': 0.9332591533660889,
#  'alfredo': 0.928644448518753,
#  'amendola': 0.936097902059555,
#  'amministratori': 0.13145063146948816,
#  'aneurismi': 0.13924963921308517,
#  'annunziata': 0.927486139535904,
#  'antonello': 0.9130688488483429,
#  'asportazione': 0.13446995317935945,
#  'assestamento': 0.11908338293433189,
#  'assistibilitã': 0.1497451439499855,
#  'attilio': 0.9212391257286072,
#  'aum': 0.14159672036767007,
#  'barbara': 0.9044173955917358,
#  'bimbo': 0.12682541981339454,
#  'capital': 0.9046370327472687,
#  'carla': 0.9009617328643799,
#  'carmelo': 0.9094054043293,
#  'carmine': 0.9197932660579682,
#  'cassagest': 0.1443023756146431,
#  'cf': 0.1244855098426342,
#  'cfu': 0.13114324808120728,
#  'charset': 0.917548394203186,
#  'chiara': 0.9434709072113037,
#  'cinzia': 0.912238609790802,
#  'colombo': 0.950298011302948,
#  'congrua': 0.1438427150249481,
#  'content': 0.939330929517746,
#  'cosimo': 0.9123241186141968,
#  'cottimisti': 0.1421849921345711,
#  'creatore': 0.1285174660384655,
#  'credit': 0.906982135772705,
#  'crocetta': 0.13438351601362228,
#  'curricolare': 0.14531125724315644,
#  'dolose': 0.14038545042276382,
#  'dtd': 0.9136543214321137,
#  'duvri': 0.14451494216918945,
#  'elisabetta': 0.9238227367401123,
#  'emiliano': 0.9417762696743012,
#  'enzo': 0.9082315564155579,
#  'equiv': 0.93747279047966,
#  'ernesto': 0.900646710395813,
#  'eugenio': 0.9168656766414642,
#  'faiotto': 0.9192614376544952,
#  'family': 0.9192859947681427,
#  'filbi': 0.916300767660141,
#  'fiorenza': 0.9518125057220459,
#  'fontana': 0.9477213382720947,
#  'gaetano': 0.9155920207500458,
#  'generator': 0.9262929022312164,
#  'gentile': 0.9144628584384918,
#  'gianluca': 0.9069877386093139,
#  'gilberto': 0.9198884308338166,
#  'giovanna': 0.9078963279724122,
#  'giuseppina': 0.9461647391319274,
#  'gobbi': 0.9471414089202881,
#  'holding': 0.9007100045681,
#  'html': 0.9413021504878998,
#  'ilaria': 0.9177269458770752,
#  'ingegneristiche': 0.1381426088511944,
#  'invitano': 0.14440219104290009,
#  'ione': 0.1476287215948105,
#  'isabella': 0.9019553661346436,
#  'ivano': 0.9096278250217438,
#  'leo': 0.9073703050613403,
#  'leonardo': 0.9000321686267853,
#  'loredana': 0.9556250631809234,
#  'luigino': 0.9542036771774292,
#  'marchetti': 0.9112521886825562,
#  'martuccelli': 0.9263684809207916,
#  'massa': 0.9138645172119141,
#  'mattoccia': 0.9204346656799316,
#  'merceologia': 0.14018137156963348,
#  'meta': 0.9345834195613861,
#  'michelangelo': 0.9116914749145508,
#  'name': 0.9171813011169434,
#  'odontoiatriche': 0.1422466143965721,
#  'patrizia': 0.9032580554485321,
#  'pellegrini': 0.9087298512458801,
#  'piero': 0.9230789065361023,
#  'plusâ': 0.14890820533037186,
#  'ponga': 0.14465259462594987,
#  'ponti': 0.9335698902606964,
#  'pozzo': 0.9264094114303589,
#  'promossa': 0.145769901573658,
#  'raffaella': 0.9015785276889801,
#  'resp': 0.12087670117616653,
#  'ricoverata': 0.14726902097463607,
#  'riepilogative': 0.13413332998752595,
#  'rizzo': 0.9337660610675812,
#  'rosaria': 0.9324902594089508,
#  'rossi': 0.9254015386104584,
#  'sandro': 0.9324755728244781,
#  'sans': 0.1356514312326908,
#  'santini': 0.9397749602794647,
#  'sapere': 0.14408734142780305,
#  'sassari': 0.901362007856369,
#  'sbarra': 0.9165974974632263,
#  'sigillata': 0.14730479419231415,
#  'significa': 0.1494608163833618,
#  'signor': 0.9128805160522461,
#  'silvano': 0.915505838394165,
#  'sim': 0.9023165583610535,
#  'simona': 0.9182446241378784,
#  'simone': 0.9414611041545868,
#  'sondrio': 0.9106585502624511,
#  'sonia': 0.9142271220684052,
#  'sorrentino': 0.9208323001861572,
#  'stefania': 0.9041448414325715,
#  'tarlazzi': 0.9070307672023773,
#  'tcm': 0.13621197938919066,
#  'title': 0.9270999193191528,
#  'ubi': 0.915863710641861,
#  'ugo': 0.9151732802391053,
#  'unicredit': 0.9145532131195069,
#  'us': 0.13439670503139495,
#  'utf': 0.9316631555557251,
#  'vento': 0.9170178711414337,
#  'vertebrale': 0.14593221843242646,
#  'ª': 0.9000009834766388}

# %%
# Save all SND scores
import pickle

with open('/content/drive/My Drive/dhh21/' + "SND_scores" + '.pkl', 'wb') as f:
  pickle.dump(all_snd, f, pickle.HIGHEST_PROTOCOL)

# %%
# Open all SND scores
with open('/content/drive/My Drive/dhh21/' + "SND_scores" + '.pkl', 'rb') as f:
  test = pickle.load(f)

for (key, item) in test["EN"].items():
  if "contract" in key:
    print(item, key)
# Out:
# 0.33133524656295776 contractual
# 0.3570935666561127 contract
# 0.3374549686908722 contracts
# 0.5082933962345123 contractseverancepay
# 0.48957888782024384 subcontractors
# 0.496165868639946 contractor
# 0.4308527082204819 contracted
# 0.42139846086502075 contracting
# 0.46933728754520415 contractors
# 0.5467705249786377 contracttrial
# 0.5552005469799042 contracttrialperiod

# %%
from math import sqrt
print(sqrt(2-(2*0.33)))
print(sqrt(2-(2*0.93)))
# Out:
# 1.1575836902790224
# 0.374165738677394

# %% [markdown]
# ## Percentage of abstract words per language

# %%
lowest15 = {}
for language in df['language'].unique():
  d = {}
  for (key, value) in all_snd[language].items():
    if value < 0.40:
      d["%s" %key] = value
  lowest15["%s" %language] = d

# %%
def abstract_ratio(lan):
  abstract = len(lowest15[lan])
  total = len(all_snd[lan])
  ratio = abstract/total
  return (lan, ratio)

for lan in df['language'].unique():
  print(abstract_ratio(lan))
# Out:
# ('FR', 0.12602803197034634)
# ('EN', 0.3034275785815827)
# ('DA', 0.017094017094017096)
# ('MT', 0.009408602150537635)
# ('DE', 0.021505376344086023)
# ('SL', 0.014145810663764961)
# ('LT', 0.0)
# ('SV', 0.06621004566210045)
# ('TR', 0.05172413793103448)
# ('IT', 0.10406450909883404)
# ('FI', 0.015189873417721518)
# ('BG', 0.0)
# ('SK', 0.009719222462203024)
# ('CS', 0.0)
# ('PT', 0.14953751284686537)
# ('NL', 0.13967774420946627)
# ('EL', 0.0)
# ('RO', 0.07679558011049724)
# ('HR', 0.02040816326530612)
# ('ES', 0.26329814492159476)
# ('HU', 0.02598267821452365)
# ('ET', 0.0)
# ('PL', 0.012521343198634035)
# ('KM', 0.0)
# ('VI', 0.03508771929824561)
# ('BA', 0.27980956502921445)
# ('AM', 0.026954177897574125)
# ('SR', 0.0)
